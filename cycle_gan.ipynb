# %%
# %tensorflow_version 1.x
from keras.layers import Layer, Input, Dropout, Conv2D, Activation, add, UpSampling2D, Conv2DTranspose, Flatten
from keras_contrib.layers.normalization.instancenormalization import InstanceNormalization, InputSpec
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.core import Dense
from keras.optimizers import Adam
from keras.models import Model
from keras.engine.topology import Network

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from progress.bar import Bar
import datetime
import time
import json
import csv
import sys
import os

import keras.backend as K
import tensorflow as tf
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.

# %%
# !pip install -U scipy==1.2.0
# Out:
# Collecting scipy==1.2.0
#   Downloading https://files.pythonhosted.org/packages/80/39/066ecde98f373430bf7a39a02d91c7075b01ef4fc928456e8e31577342d6/scipy-1.2.0-cp37-cp37m-manylinux1_x86_64.whl (26.6MB)
#      |████████████████████████████████| 26.6MB 115kB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from scipy==1.2.0) (1.19.5)
# ERROR: lucid 0.3.10 requires umap-learn, which is not installed.
# ERROR: lucid 0.3.10 has requirement numpy<=1.19, but you'll have numpy 1.19.5 which is incompatible.
# ERROR: kapre 0.3.5 has requirement tensorflow>=2.0.0, but you'll have tensorflow 1.15.2 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: scipy
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# Successfully installed scipy-1.2.0

# %%
'''from keras.layers import Layer, Input, Conv2D, Activation, add, BatchNormalization, UpSampling2D, ZeroPadding2D, Conv2DTranspose, Flatten, MaxPooling2D, AveragePooling2D
from keras_contrib.layers.normalization.instancenormalization import InstanceNormalization, InputSpec
'''
import os
from PIL import Image
import glob
'''
#from keras_contrib.layers.normalization import InstanceNormalization, InputSpec
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.core import Dense
from keras.optimizers import Adam
from keras.backend import mean
from keras.models import Model, model_from_json
from keras.utils import plot_model
from keras.engine.topology import Network
'''
from collections import OrderedDict
from scipy.misc import imsave, toimage  # has depricated
'''import numpy as np
import random
import datetime
import time
import json
import math
import csv
import sys
import os

import keras.backend as K
import tensorflow as tf
'''
#import load_data

# %tensorflow_version 1.x
from keras.layers import Layer, Input, Dropout, Conv2D, Activation, add, UpSampling2D, \
    Conv2DTranspose, Flatten
from keras_contrib.layers.normalization.instancenormalization import InstanceNormalization, InputSpec
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.core import Dense
from keras.optimizers import Adam
from keras.models import Model
from keras.engine.topology import Network

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from progress.bar import Bar
import datetime
import time
import json
import csv
import sys
import os
import random

import keras.backend as K
import tensorflow as tf

def load_data(nr_of_channels, batch_size=1, nr_A_train_imgs=None, nr_B_train_imgs=None,
              nr_A_test_imgs=None, nr_B_test_imgs=None, subfolder='',
              generator=False, D_model=None, use_multiscale_discriminator=False, use_supervised_learning=False, REAL_LABEL=1.0):

    trainA_path = os.path.join('data', subfolder, 'trainA')
    trainB_path = os.path.join('data', subfolder, 'trainB')
    testA_path = os.path.join('data', subfolder, 'testA')
    testB_path = os.path.join('data', subfolder, 'testB')

    trainA_image_names = os.listdir(trainA_path)
    if nr_A_train_imgs != None:
        trainA_image_names = trainA_image_names[:nr_A_train_imgs]

    trainB_image_names = os.listdir(trainB_path)
    if nr_B_train_imgs != None:
        trainB_image_names = trainB_image_names[:nr_B_train_imgs]

    testA_image_names = os.listdir(testA_path)
    if nr_A_test_imgs != None:
        testA_image_names = testA_image_names[:nr_A_test_imgs]

    testB_image_names = os.listdir(testB_path)
    if nr_B_test_imgs != None:
        testB_image_names = testB_image_names[:nr_B_test_imgs]

    if generator:
        return data_sequence(trainA_path, trainB_path, trainA_image_names, trainB_image_names, batch_size=batch_size)  # D_model, use_multiscale_discriminator, use_supervised_learning, REAL_LABEL)
    else:
        trainA_images = create_image_array(trainA_image_names, trainA_path, nr_of_channels)
        trainB_images = create_image_array(trainB_image_names, trainB_path, nr_of_channels)
        testA_images = create_image_array(testA_image_names, testA_path, nr_of_channels)
        testB_images = create_image_array(testB_image_names, testB_path, nr_of_channels)
        return {"trainA_images": trainA_images, "trainB_images": trainB_images,
                "testA_images": testA_images, "testB_images": testB_images,
                "trainA_image_names": trainA_image_names,
                "trainB_image_names": trainB_image_names,
                "testA_image_names": testA_image_names,
                "testB_image_names": testB_image_names}


def create_image_array(image_list, image_path, nr_of_channels):
    image_array = []
    for image_name in image_list:
        if image_name[-1].lower() == 'g':  # to avoid e.g. thumbs.db files
            if nr_of_channels == 1:  # Gray scale image -> MR image
                image = np.array(Image.open(os.path.join(image_path, image_name)))
                image = image[:, :, np.newaxis]
            else:                   # RGB image -> 3 channels
                image = np.array(Image.open(os.path.join(image_path, image_name)))
            image = normalize_array(image)
            image_array.append(image)

    return np.array(image_array)


  # If using 16 bit depth images, use the formula 'array = array / 32767.5 - 1' instead
def normalize_array(array):
    array = array / 127.5 - 1
    return array


class data_sequence():

    def __init__(self, trainA_path, trainB_path, image_list_A, image_list_B, batch_size=1):  # , D_model, use_multiscale_discriminator, use_supervised_learning, REAL_LABEL):
        self.batch_size = batch_size
        self.train_A = []
        self.train_B = []
        for image_name in image_list_A:
            if image_name[-1].lower() == 'g':  # to avoid e.g. thumbs.db files
                self.train_A.append(os.path.join(trainA_path, image_name))
        for image_name in image_list_B:
            if image_name[-1].lower() == 'g':  # to avoid e.g. thumbs.db files
                self.train_B.append(os.path.join(trainB_path, image_name))

    def __len__(self):
        return int(max(len(self.train_A), len(self.train_B)) / float(self.batch_size))

    def __getitem__(self, idx):  # , use_multiscale_discriminator, use_supervised_learning):if loop_index + batch_size >= min_nr_imgs:
        if idx >= min(len(self.train_A), len(self.train_B)):
            # If all images soon are used for one domain,
            # randomly pick from this domain
            if len(self.train_A) <= len(self.train_B):
                indexes_A = np.random.randint(len(self.train_A), size=self.batch_size)
                batch_A = []
                for i in indexes_A:
                    batch_A.append(self.train_A[i])
                batch_B = self.train_B[idx * self.batch_size:(idx + 1) * self.batch_size]
            else:
                indexes_B = np.random.randint(len(self.train_B), size=self.batch_size)
                batch_B = []
                for i in indexes_B:
                    batch_B.append(self.train_B[i])
                batch_A = self.train_A[idx * self.batch_size:(idx + 1) * self.batch_size]
        else:
            batch_A = self.train_A[idx * self.batch_size:(idx + 1) * self.batch_size]
            batch_B = self.train_B[idx * self.batch_size:(idx + 1) * self.batch_size]

        real_images_A = create_image_array(batch_A, '', 3)
        real_images_B = create_image_array(batch_B, '', 3)

        return real_images_A, real_images_B  # input_data, target_data




np.random.seed(seed=12345)


class CycleGAN():
    def __init__(self, lr_D=2e-4, lr_G=2e-4, image_shape=(240, 240, 1),
                 date_time_string_addition='', image_folder='MR'):
        self.img_shape = image_shape
        self.channels = self.img_shape[-1]
        self.normalization = InstanceNormalization
        # Hyper parameters
        self.lambda_1 = 10.0  # Cyclic loss weight A_2_B
        self.lambda_2 = 10.0  # Cyclic loss weight B_2_A
        self.lambda_D = 1.0  # Weight for loss from discriminator guess on synthetic images
        self.learning_rate_D = lr_D
        self.learning_rate_G = lr_G
        self.generator_iterations = 1  # Number of generator training iterations in each training loop
        self.discriminator_iterations = 1  # Number of generator training iterations in each training loop
        self.beta_1 = 0.5
        self.beta_2 = 0.999
        self.batch_size = 1
        self.epochs = 100  # choose multiples of 25 since the models are save each 25th epoch
        self.save_interval = 1
        self.synthetic_pool_size = 50

        # Linear decay of learning rate, for both discriminators and generators
        self.use_linear_decay = True
        self.decay_epoch = 101  # The epoch where the linear decay of the learning rates start

        # Identity loss - sometimes send images from B to G_A2B (and the opposite) to teach identity mappings
        self.use_identity_learning = False
        self.identity_mapping_modulus = 10  # Identity mapping will be done each time the iteration number is divisable with this number

        # PatchGAN - if false the discriminator learning rate should be decreased
        self.use_patchgan = True

        # Multi scale discriminator - if True the generator have an extra encoding/decoding step to match discriminator information access
        self.use_multiscale_discriminator = False

        # Resize convolution - instead of transpose convolution in deconvolution layers (uk) - can reduce checkerboard artifacts but the blurring might affect the cycle-consistency
        self.use_resize_convolution = False

        # Supervised learning part - for MR images - comparison
        self.use_supervised_learning = False
        self.supervised_weight = 10.0

        # Fetch data during training instead of pre caching all images - might be necessary for large datasets
        self.use_data_generator = False

        # Tweaks
        self.REAL_LABEL = 1.0  # Use e.g. 0.9 to avoid training the discriminators to zero loss

        # Used as storage folder name
        self.date_time = time.strftime('%Y%m%d-%H%M%S', time.localtime()) + date_time_string_addition

        # optimizer
        self.opt_D = Adam(self.learning_rate_D, self.beta_1, self.beta_2)
        self.opt_G = Adam(self.learning_rate_G, self.beta_1, self.beta_2)

        # ======= Discriminator model ==========
        if self.use_multiscale_discriminator:
            D_A = self.modelMultiScaleDiscriminator()
            D_B = self.modelMultiScaleDiscriminator()
            loss_weights_D = [0.5, 0.5] # 0.5 since we train on real and synthetic images
        else:
            D_A = self.modelDiscriminator()
            D_B = self.modelDiscriminator()
            loss_weights_D = [0.5]  # 0.5 since we train on real and synthetic images
        # D_A.summary()

        # Discriminator builds
        image_A = Input(shape=self.img_shape)
        image_B = Input(shape=self.img_shape)
        guess_A = D_A(image_A)
        guess_B = D_B(image_B)
        self.D_A = Model(inputs=image_A, outputs=guess_A, name='D_A_model')
        self.D_B = Model(inputs=image_B, outputs=guess_B, name='D_B_model')

        # self.D_A.summary()
        # self.D_B.summary()
        self.D_A.compile(optimizer=self.opt_D,
                         loss=self.lse,
                         loss_weights=loss_weights_D)
        self.D_B.compile(optimizer=self.opt_D,
                         loss=self.lse,
                         loss_weights=loss_weights_D)

        # Use Networks to avoid falsy keras error about weight descripancies
        self.D_A_static = Network(inputs=image_A, outputs=guess_A, name='D_A_static_model')
        self.D_B_static = Network(inputs=image_B, outputs=guess_B, name='D_B_static_model')

        # ======= Generator model ==========
        # Do note update discriminator weights during generator training
        self.D_A_static.trainable = False
        self.D_B_static.trainable = False

        # Generators
        self.G_A2B = self.modelGenerator(name='G_A2B_model')
        self.G_B2A = self.modelGenerator(name='G_B2A_model')
        # self.G_A2B.summary()

        if self.use_identity_learning:
            self.G_A2B.compile(optimizer=self.opt_G, loss='MAE')
            self.G_B2A.compile(optimizer=self.opt_G, loss='MAE')

        # Generator builds
        real_A = Input(shape=self.img_shape, name='real_A')
        real_B = Input(shape=self.img_shape, name='real_B')
        synthetic_B = self.G_A2B(real_A)
        synthetic_A = self.G_B2A(real_B)
        dA_guess_synthetic = self.D_A_static(synthetic_A)
        dB_guess_synthetic = self.D_B_static(synthetic_B)
        reconstructed_A = self.G_B2A(synthetic_B)
        reconstructed_B = self.G_A2B(synthetic_A)

        model_outputs = [reconstructed_A, reconstructed_B]
        compile_losses = [self.cycle_loss, self.cycle_loss,
                          self.lse, self.lse]
        compile_weights = [self.lambda_1, self.lambda_2,
                           self.lambda_D, self.lambda_D]

        if self.use_multiscale_discriminator:
            for _ in range(2):
                compile_losses.append(self.lse)
                compile_weights.append(self.lambda_D)  # * 1e-3)  # Lower weight to regularize the model
            for i in range(2):
                model_outputs.append(dA_guess_synthetic[i])
                model_outputs.append(dB_guess_synthetic[i])
        else:
            model_outputs.append(dA_guess_synthetic)
            model_outputs.append(dB_guess_synthetic)

        if self.use_supervised_learning:
            model_outputs.append(synthetic_A)
            model_outputs.append(synthetic_B)
            compile_losses.append('MAE')
            compile_losses.append('MAE')
            compile_weights.append(self.supervised_weight)
            compile_weights.append(self.supervised_weight)

        self.G_model = Model(inputs=[real_A, real_B],
                             outputs=model_outputs,
                             name='G_model')

        self.G_model.compile(optimizer=self.opt_G,
                             loss=compile_losses,
                             loss_weights=compile_weights)
        # self.G_A2B.summary()

        # ======= Data ==========
        # Use 'None' to fetch all available images
        nr_A_train_imgs = None
        nr_B_train_imgs = None
        nr_A_test_imgs = None
        nr_B_test_imgs = None

        if self.use_data_generator:
            print('--- Using dataloader during training ---')
        else:
            print('--- Caching data ---')
        sys.stdout.flush()

        if self.use_data_generator:
            self.data_generator = load_data(
                nr_of_channels=self.batch_size, generator=True, subfolder=image_folder)

            # Only store test images
            nr_A_train_imgs = 0
            nr_B_train_imgs = 0

        data = load_data(nr_of_channels=self.channels,
                                   batch_size=self.batch_size,
                                   nr_A_train_imgs=nr_A_train_imgs,
                                   nr_B_train_imgs=nr_B_train_imgs,
                                   nr_A_test_imgs=nr_A_test_imgs,
                                   nr_B_test_imgs=nr_B_test_imgs,
                                   subfolder=image_folder)

        self.A_train = data["trainA_images"]
        self.B_train = data["trainB_images"]
        self.A_test = data["testA_images"]
        self.B_test = data["testB_images"]
        self.testA_image_names = data["testA_image_names"]
        self.testB_image_names = data["testB_image_names"]
        if not self.use_data_generator:
            print('Data has been loaded')

        # ======= Create designated run folder and store meta data ==========
        directory = os.path.join('images', self.date_time)
        if not os.path.exists(directory):
            os.makedirs(directory)
        self.writeMetaDataToJSON()

        # ======= Avoid pre-allocating GPU memory ==========
        # TensorFlow wizardry
        #config = tf.ConfigProto()
        config=tf.compat.v1.ConfigProto()

        # Don't pre-allocate memory; allocate as-needed
        config.gpu_options.allow_growth = True

        # Create a session with the above options specified.
        K.tensorflow_backend.set_session(tf.Session(config=config))

        # ===== Tests ======
        # Simple Model
#         self.G_A2B = self.modelSimple('simple_T1_2_T2_model')
#         self.G_B2A = self.modelSimple('simple_T2_2_T1_model')
#         self.G_A2B.compile(optimizer=Adam(), loss='MAE')
#         self.G_B2A.compile(optimizer=Adam(), loss='MAE')
#         # self.trainSimpleModel()
#         self.load_model_and_generate_synthetic_images()

        # ======= Initialize training ==========
        sys.stdout.flush()
        #plot_model(self.G_A2B, to_file='GA2B_expanded_model_new.png', show_shapes=True)
        self.train(epochs=self.epochs, batch_size=self.batch_size, save_interval=self.save_interval)
        #self.load_model_and_generate_synthetic_images()

#===============================================================================
# Architecture functions

    def ck(self, x, k, use_normalization, stride):
        x = Conv2D(filters=k, kernel_size=4, strides=stride, padding='same')(x)
        # Normalization is not done on the first discriminator layer
        if use_normalization:
            x = self.normalization(axis=3, center=True, epsilon=1e-5)(x, training=True)
        x = LeakyReLU(alpha=0.2)(x)
        return x

    def c7Ak(self, x, k):
        x = Conv2D(filters=k, kernel_size=7, strides=1, padding='valid')(x)
        x = self.normalization(axis=3, center=True, epsilon=1e-5)(x, training=True)
        x = Activation('relu')(x)
        return x

    def dk(self, x, k):
        x = Conv2D(filters=k, kernel_size=3, strides=2, padding='same')(x)
        x = self.normalization(axis=3, center=True, epsilon=1e-5)(x, training=True)
        x = Activation('relu')(x)
        return x

    def Rk(self, x0):
        k = int(x0.shape[-1])
        # first layer
        x = Conv2D(filters=k, kernel_size=3, strides=1, padding='same')(x0)
        x = self.normalization(axis=3, center=True, epsilon=1e-5)(x, training=True)
        x = Activation('relu')(x)
        # second layer
        x = Conv2D(filters=k, kernel_size=3, strides=1, padding='same')(x)
        x = self.normalization(axis=3, center=True, epsilon=1e-5)(x, training=True)
        # merge
        x = add([x, x0])
        return x

    def uk(self, x, k):
        # (up sampling followed by 1x1 convolution <=> fractional-strided 1/2)
        if self.use_resize_convolution:
            x = UpSampling2D(size=(2, 2))(x)  # Nearest neighbor upsampling
            x = ReflectionPadding2D((1, 1))(x)
            x = Conv2D(filters=k, kernel_size=3, strides=1, padding='valid')(x)
        else:
            x = Conv2DTranspose(filters=k, kernel_size=3, strides=2, padding='same')(x)  # this matches fractionally stided with stride 1/2
        x = self.normalization(axis=3, center=True, epsilon=1e-5)(x, training=True)
        x = Activation('relu')(x)
        return x

#===============================================================================
# Models

    def modelMultiScaleDiscriminator(self, name=None):
        x1 = Input(shape=self.img_shape)
        x2 = AveragePooling2D(pool_size=(2, 2))(x1)
        #x4 = AveragePooling2D(pool_size=(2, 2))(x2)

        out_x1 = self.modelDiscriminator('D1')(x1)
        out_x2 = self.modelDiscriminator('D2')(x2)
        #out_x4 = self.modelDiscriminator('D4')(x4)

        return Model(inputs=x1, outputs=[out_x1, out_x2], name=name)

    def modelDiscriminator(self, name=None):
        # Specify input
        input_img = Input(shape=self.img_shape)
        # Layer 1 (#Instance normalization is not used for this layer)
        x = self.ck(input_img, 64, False, 2)
        # Layer 2
        x = self.ck(x, 128, True, 2)
        # Layer 3
        x = self.ck(x, 256, True, 2)
        # Layer 4
        x = self.ck(x, 512, True, 1)
        # Output layer
        if self.use_patchgan:
            x = Conv2D(filters=1, kernel_size=4, strides=1, padding='same')(x)
        else:
            x = Flatten()(x)
            x = Dense(1)(x)
        #x = Activation('sigmoid')(x) - No sigmoid to avoid near-fp32 machine epsilon discriminator cost
        return Model(inputs=input_img, outputs=x, name=name)

    def modelGenerator(self, name=None):
        # Specify input
        input_img = Input(shape=self.img_shape)
        # Layer 1
        x = ReflectionPadding2D((3, 3))(input_img)
        x = self.c7Ak(x, 32)
        # Layer 2
        x = self.dk(x, 64)
        # Layer 3
        x = self.dk(x, 128)

        if self.use_multiscale_discriminator:
            # Layer 3.5
            x = self.dk(x, 256)

        # Layer 4-12: Residual layer
        for _ in range(4, 13):
            x = self.Rk(x)

        if self.use_multiscale_discriminator:
            # Layer 12.5
            x = self.uk(x, 128)

        # Layer 13
        x = self.uk(x, 64)
        # Layer 14
        x = self.uk(x, 32)
        x = ReflectionPadding2D((3, 3))(x)
        x = Conv2D(self.channels, kernel_size=7, strides=1)(x)
        x = Activation('tanh')(x)  # They say they use Relu but really they do not
        return Model(inputs=input_img, outputs=x, name=name)

#===============================================================================
# Test - simple model
    def modelSimple(self, name=None):
        inputImg = Input(shape=self.img_shape)
        #x = Conv2D(1, kernel_size=5, strides=1, padding='same')(inputImg)
        #x = Dense(self.channels)(x)
        x = Conv2D(256, kernel_size=1, strides=1, padding='same')(inputImg)
        x = Activation('relu')(x)
        x = Conv2D(self.channels, kernel_size=1, strides=1, padding='same')(x)

        return Model(input=inputImg, output=x, name=name)

    def trainSimpleModel(self):
        real_A = self.A_test[0]
        real_B = self.B_test[0]
        real_A = real_A[np.newaxis, :, :, :]
        real_B = real_B[np.newaxis, :, :, :]
        epochs = 200
        for epoch in range(epochs):
            print('Epoch {} started'.format(epoch))
            self.G_A2B.fit(x=self.A_train, y=self.B_train, epochs=1, batch_size=1)
            self.G_B2A.fit(x=self.B_train, y=self.A_train, epochs=1, batch_size=1)
            #loss = self.G_A2B.train_on_batch(x=real_A, y=real_B)
            #print('loss: ', loss)
            synthetic_image_A = self.G_B2A.predict(real_B, batch_size=1)
            synthetic_image_B = self.G_A2B.predict(real_A, batch_size=1)
            self.save_tmp_images(real_A, real_B, synthetic_image_A, synthetic_image_B)

        self.saveModel(self.G_A2B, 200)
        self.saveModel(self.G_B2A, 200)

#===============================================================================
# Training
    def train(self, epochs, batch_size=1, save_interval=1):
        def run_training_iteration(loop_index, epoch_iterations):
            # ======= Discriminator training ==========
                # Generate batch of synthetic images
            synthetic_images_B = self.G_A2B.predict(real_images_A)
            synthetic_images_A = self.G_B2A.predict(real_images_B)
            synthetic_images_A = synthetic_pool_A.query(synthetic_images_A)
            synthetic_images_B = synthetic_pool_B.query(synthetic_images_B)

            for _ in range(self.discriminator_iterations):
                DA_loss_real = self.D_A.train_on_batch(x=real_images_A, y=ones)
                DB_loss_real = self.D_B.train_on_batch(x=real_images_B, y=ones)
                DA_loss_synthetic = self.D_A.train_on_batch(x=synthetic_images_A, y=zeros)
                DB_loss_synthetic = self.D_B.train_on_batch(x=synthetic_images_B, y=zeros)
                if self.use_multiscale_discriminator:
                    DA_loss = sum(DA_loss_real) + sum(DA_loss_synthetic)
                    DB_loss = sum(DB_loss_real) + sum(DB_loss_synthetic)
                    print('DA_losses: ', np.add(DA_loss_real, DA_loss_synthetic))
                    print('DB_losses: ', np.add(DB_loss_real, DB_loss_synthetic))
                else:
                    DA_loss = DA_loss_real + DA_loss_synthetic
                    DB_loss = DB_loss_real + DB_loss_synthetic
                D_loss = DA_loss + DB_loss

                if self.discriminator_iterations > 1:
                    print('D_loss:', D_loss)
                    sys.stdout.flush()

            # ======= Generator training ==========
            target_data = [real_images_A, real_images_B]  # Compare reconstructed images to real images
            if self.use_multiscale_discriminator:
                for i in range(2):
                    target_data.append(ones[i])
                    target_data.append(ones[i])
            else:
                target_data.append(ones)
                target_data.append(ones)

            if self.use_supervised_learning:
                target_data.append(real_images_A)
                target_data.append(real_images_B)

            for _ in range(self.generator_iterations):
                G_loss = self.G_model.train_on_batch(
                    x=[real_images_A, real_images_B], y=target_data)
                if self.generator_iterations > 1:
                    print('G_loss:', G_loss)
                    sys.stdout.flush()

            gA_d_loss_synthetic = G_loss[1]
            gB_d_loss_synthetic = G_loss[2]
            reconstruction_loss_A = G_loss[3]
            reconstruction_loss_B = G_loss[4]

            # Identity training
            if self.use_identity_learning and loop_index % self.identity_mapping_modulus == 0:
                G_A2B_identity_loss = self.G_A2B.train_on_batch(
                    x=real_images_B, y=real_images_B)
                G_B2A_identity_loss = self.G_B2A.train_on_batch(
                    x=real_images_A, y=real_images_A)
                print('G_A2B_identity_loss:', G_A2B_identity_loss)
                print('G_B2A_identity_loss:', G_B2A_identity_loss)

            # Update learning rates
            if self.use_linear_decay and epoch > self.decay_epoch:
                self.update_lr(self.D_A, decay_D)
                self.update_lr(self.D_B, decay_D)
                self.update_lr(self.G_model, decay_G)

            # Store training data
            DA_losses.append(DA_loss)
            DB_losses.append(DB_loss)
            gA_d_losses_synthetic.append(gA_d_loss_synthetic)
            gB_d_losses_synthetic.append(gB_d_loss_synthetic)
            gA_losses_reconstructed.append(reconstruction_loss_A)
            gB_losses_reconstructed.append(reconstruction_loss_B)

            GA_loss = gA_d_loss_synthetic + reconstruction_loss_A
            GB_loss = gB_d_loss_synthetic + reconstruction_loss_B
            D_losses.append(D_loss)
            GA_losses.append(GA_loss)
            GB_losses.append(GB_loss)
            G_losses.append(G_loss)
            reconstruction_loss = reconstruction_loss_A + reconstruction_loss_B
            reconstruction_losses.append(reconstruction_loss)

            print('\n')
            print('Epoch----------------', epoch, '/', epochs)
            print('Loop index----------------', loop_index + 1, '/', epoch_iterations)
            print('D_loss: ', D_loss)
            print('G_loss: ', G_loss[0])
            print('reconstruction_loss: ', reconstruction_loss)
            print('dA_loss:', DA_loss)
            print('DB_loss:', DB_loss)

            if loop_index % 20 == 0:
                # Save temporary images continously
                self.save_tmp_images(real_images_A, real_images_B, synthetic_images_A, synthetic_images_B)
                self.print_ETA(start_time, epoch, epoch_iterations, loop_index)

        # ======================================================================
        # Begin training
        # ======================================================================
        training_history = OrderedDict()

        DA_losses = []
        DB_losses = []
        gA_d_losses_synthetic = []
        gB_d_losses_synthetic = []
        gA_losses_reconstructed = []
        gB_losses_reconstructed = []

        GA_losses = []
        GB_losses = []
        reconstruction_losses = []
        D_losses = []
        G_losses = []

        # Image pools used to update the discriminators
        synthetic_pool_A = ImagePool(self.synthetic_pool_size)
        synthetic_pool_B = ImagePool(self.synthetic_pool_size)

        # self.saveImages('(init)')

        # labels
        if self.use_multiscale_discriminator:
            label_shape1 = (batch_size,) + self.D_A.output_shape[0][1:]
            label_shape2 = (batch_size,) + self.D_A.output_shape[1][1:]
            #label_shape4 = (batch_size,) + self.D_A.output_shape[2][1:]
            ones1 = np.ones(shape=label_shape1) * self.REAL_LABEL
            ones2 = np.ones(shape=label_shape2) * self.REAL_LABEL
            #ones4 = np.ones(shape=label_shape4) * self.REAL_LABEL
            ones = [ones1, ones2]  # , ones4]
            zeros1 = ones1 * 0
            zeros2 = ones2 * 0
            #zeros4 = ones4 * 0
            zeros = [zeros1, zeros2]  # , zeros4]
        else:
            label_shape = (batch_size,) + self.D_A.output_shape[1:]
            ones = np.ones(shape=label_shape) * self.REAL_LABEL
            zeros = ones * 0

        # Linear decay
        if self.use_linear_decay:
            decay_D, decay_G = self.get_lr_linear_decay_rate()

        # Start stopwatch for ETAs
        start_time = time.time()

        for epoch in range(1, epochs + 1):
            if self.use_data_generator:
                loop_index = 1
                for images in self.data_generator:
                    real_images_A = images[0]
                    real_images_B = images[1]
                    if len(real_images_A.shape) == 3:
                        real_images_A = real_images_A[:, :, :, np.newaxis]
                        real_images_B = real_images_B[:, :, :, np.newaxis]

                    # Run all training steps
                    run_training_iteration(loop_index, self.data_generator.__len__())

                    # Store models
                    if loop_index % 20000 == 0:
                        self.saveModel(self.D_A, loop_index)
                        self.saveModel(self.D_B, loop_index)
                        self.saveModel(self.G_A2B, loop_index)
                        self.saveModel(self.G_B2A, loop_index)

                    # Break if loop has ended
                    if loop_index >= self.data_generator.__len__():
                        break

                    loop_index += 1

            else:  # Train with all data in cache
                A_train = self.A_train
                B_train = self.B_train
                random_order_A = np.random.randint(len(A_train), size=len(A_train))
                random_order_B = np.random.randint(len(B_train), size=len(B_train))
                epoch_iterations = max(len(random_order_A), len(random_order_B))
                min_nr_imgs = min(len(random_order_A), len(random_order_B))

                # If we want supervised learning the same images form
                # the two domains are needed during each training iteration
                if self.use_supervised_learning:
                    random_order_B = random_order_A
                for loop_index in range(0, epoch_iterations, batch_size):
                    if loop_index + batch_size >= min_nr_imgs:
                        # If all images soon are used for one domain,
                        # randomly pick from this domain
                        if len(A_train) <= len(B_train):
                            indexes_A = np.random.randint(len(A_train), size=batch_size)

                            # if all images are used for the other domain
                            if loop_index + batch_size >= epoch_iterations:
                                indexes_B = random_order_B[epoch_iterations-batch_size:
                                                           epoch_iterations]
                            else: # if not used, continue iterating...
                                indexes_B = random_order_B[loop_index:
                                                           loop_index + batch_size]

                        else: # if len(B_train) <= len(A_train)
                            indexes_B = np.random.randint(len(B_train), size=batch_size)

                             # if all images are used for the other domain
                            if loop_index + batch_size >= epoch_iterations:
                                indexes_A = random_order_A[epoch_iterations-batch_size:
                                                           epoch_iterations]
                            else: # if not used, continue iterating...
                                indexes_A = random_order_A[loop_index:
                                                           loop_index + batch_size]

                    else:
                        indexes_A = random_order_A[loop_index:
                                                   loop_index + batch_size]
                        indexes_B = random_order_B[loop_index:
                                                   loop_index + batch_size]

                    sys.stdout.flush()
                    real_images_A = A_train[indexes_A]
                    real_images_B = B_train[indexes_B]

                    # Run all training steps
                    run_training_iteration(loop_index, epoch_iterations)

            #================== within epoch loop end ==========================

            if epoch % save_interval == 0:
                print('\n', '\n', '-------------------------Saving images for epoch', epoch, '-------------------------', '\n', '\n')
                self.saveImages(epoch, real_images_A, real_images_B)

            if epoch % 20 == 0:
                # self.saveModel(self.G_model)
                self.saveModel(self.D_A, epoch)
                self.saveModel(self.D_B, epoch)
                self.saveModel(self.G_A2B, epoch)
                self.saveModel(self.G_B2A, epoch)

            training_history = {
                'DA_losses': DA_losses,
                'DB_losses': DB_losses,
                'gA_d_losses_synthetic': gA_d_losses_synthetic,
                'gB_d_losses_synthetic': gB_d_losses_synthetic,
                'gA_losses_reconstructed': gA_losses_reconstructed,
                'gB_losses_reconstructed': gB_losses_reconstructed,
                'D_losses': D_losses,
                'G_losses': G_losses,
                'reconstruction_losses': reconstruction_losses}
            self.writeLossDataToFile(training_history)

            # Flush out prints each loop iteration
            sys.stdout.flush()

#===============================================================================
# Help functions

    def lse(self, y_true, y_pred):
        loss = tf.reduce_mean(tf.squared_difference(y_pred, y_true))
        return loss

    def cycle_loss(self, y_true, y_pred):
        loss = tf.reduce_mean(tf.abs(y_pred - y_true))
        return loss

    def truncateAndSave(self, real_, real, synthetic, reconstructed, path_name):
        if len(real.shape) > 3:
            real = real[0]
            synthetic = synthetic[0]
            reconstructed = reconstructed[0]

        # Append and save
        if real_ is not None:
            if len(real_.shape) > 4:
                real_ = real_[0]
            image = np.hstack((real_[0], real, synthetic, reconstructed))
        else:
            image = np.hstack((real, synthetic, reconstructed))

        if self.channels == 1:
            image = image[:, :, 0]

        toimage(image, cmin=-1, cmax=1).save(path_name)

    def saveImages(self, epoch, real_image_A, real_image_B, num_saved_images=1):
        directory = os.path.join('images', self.date_time)
        if not os.path.exists(os.path.join(directory, 'A')):
            os.makedirs(os.path.join(directory, 'A'))
            os.makedirs(os.path.join(directory, 'B'))
            os.makedirs(os.path.join(directory, 'Atest'))
            os.makedirs(os.path.join(directory, 'Btest'))

        testString = ''

        real_image_Ab = None
        real_image_Ba = None
        for i in range(num_saved_images + 1):
            if i == num_saved_images:
                real_image_A = self.A_test[0]
                real_image_B = self.B_test[0]
                real_image_A = np.expand_dims(real_image_A, axis=0)
                real_image_B = np.expand_dims(real_image_B, axis=0)
                testString = 'test'
                if self.channels == 1:  # Use the paired data for MR images
                    real_image_Ab = self.B_test[0]
                    real_image_Ba = self.A_test[0]
                    real_image_Ab = np.expand_dims(real_image_Ab, axis=0)
                    real_image_Ba = np.expand_dims(real_image_Ba, axis=0)
            else:
                #real_image_A = self.A_train[rand_A_idx[i]]
                #real_image_B = self.B_train[rand_B_idx[i]]
                if len(real_image_A.shape) < 4:
                    real_image_A = np.expand_dims(real_image_A, axis=0)
                    real_image_B = np.expand_dims(real_image_B, axis=0)
                if self.channels == 1:  # Use the paired data for MR images
                    real_image_Ab = real_image_B  # self.B_train[rand_A_idx[i]]
                    real_image_Ba = real_image_A  # self.A_train[rand_B_idx[i]]
                    real_image_Ab = np.expand_dims(real_image_Ab, axis=0)
                    real_image_Ba = np.expand_dims(real_image_Ba, axis=0)

            synthetic_image_B = self.G_A2B.predict(real_image_A)
            synthetic_image_A = self.G_B2A.predict(real_image_B)
            reconstructed_image_A = self.G_B2A.predict(synthetic_image_B)
            reconstructed_image_B = self.G_A2B.predict(synthetic_image_A)

            self.truncateAndSave(real_image_Ab, real_image_A, synthetic_image_B, reconstructed_image_A,
                                 'images/{}/{}/epoch{}_sample{}.png'.format(
                                     self.date_time, 'A' + testString, epoch, i))
            self.truncateAndSave(real_image_Ba, real_image_B, synthetic_image_A, reconstructed_image_B,
                                 'images/{}/{}/epoch{}_sample{}.png'.format(
                                     self.date_time, 'B' + testString, epoch, i))

    def save_tmp_images(self, real_image_A, real_image_B, synthetic_image_A, synthetic_image_B):
        try:
            reconstructed_image_A = self.G_B2A.predict(synthetic_image_B)
            reconstructed_image_B = self.G_A2B.predict(synthetic_image_A)

            real_images = np.vstack((real_image_A[0], real_image_B[0]))
            synthetic_images = np.vstack((synthetic_image_B[0], synthetic_image_A[0]))
            reconstructed_images = np.vstack((reconstructed_image_A[0], reconstructed_image_B[0]))

            self.truncateAndSave(None, real_images, synthetic_images, reconstructed_images,
                                 'images/{}/{}.png'.format(
                                     self.date_time, 'tmp'))
        except: # Ignore if file is open
            pass

    def get_lr_linear_decay_rate(self):
        # Calculate decay rates
        if self.use_data_generator:
            max_nr_images = len(self.data_generator)
        else:
            max_nr_images = max(len(self.A_train), len(self.B_train))

        updates_per_epoch_D = 2 * max_nr_images + self.discriminator_iterations - 1
        updates_per_epoch_G = max_nr_images + self.generator_iterations - 1
        if self.use_identity_learning:
            updates_per_epoch_G *= (1 + 1 / self.identity_mapping_modulus)
        denominator_D = (self.epochs - self.decay_epoch) * updates_per_epoch_D
        denominator_G = (self.epochs - self.decay_epoch) * updates_per_epoch_G
        decay_D = self.learning_rate_D / denominator_D
        decay_G = self.learning_rate_G / denominator_G

        return decay_D, decay_G

    def update_lr(self, model, decay):
        new_lr = K.get_value(model.optimizer.lr) - decay
        if new_lr < 0:
            new_lr = 0
        # print(K.get_value(model.optimizer.lr))
        K.set_value(model.optimizer.lr, new_lr)

    def print_ETA(self, start_time, epoch, epoch_iterations, loop_index):
        passed_time = time.time() - start_time

        iterations_so_far = ((epoch - 1) * epoch_iterations + loop_index) / self.batch_size
        iterations_total = self.epochs * epoch_iterations / self.batch_size
        iterations_left = iterations_total - iterations_so_far
        eta = round(passed_time / (iterations_so_far + 1e-5) * iterations_left)

        passed_time_string = str(datetime.timedelta(seconds=round(passed_time)))
        eta_string = str(datetime.timedelta(seconds=eta))
        print('Time passed', passed_time_string, ': ETA in', eta_string)


#===============================================================================
# Save and load

    def saveModel(self, model, epoch):
        # Create folder to save model architecture and weights
        directory = os.path.join('saved_models', self.date_time)
        if not os.path.exists(directory):
            os.makedirs(directory)

        model_path_w = 'saved_models/{}/{}_weights_epoch_{}.hdf5'.format(self.date_time, model.name, epoch)
        model.save_weights(model_path_w)
        model_path_m = 'saved_models/{}/{}_model_epoch_{}.json'.format(self.date_time, model.name, epoch)
        model.save_weights(model_path_m)
        json_string = model.to_json()
        with open(model_path_m, 'w') as outfile:
            json.dump(json_string, outfile)
        print('{} has been saved in saved_models/{}/'.format(model.name, self.date_time))

    def writeLossDataToFile(self, history):
        keys = sorted(history.keys())
        with open('images/{}/loss_output.csv'.format(self.date_time), 'w') as csv_file:
            writer = csv.writer(csv_file, delimiter=',')
            writer.writerow(keys)
            writer.writerows(zip(*[history[key] for key in keys]))

    def writeMetaDataToJSON(self):

        directory = os.path.join('images', self.date_time)
        if not os.path.exists(directory):
            os.makedirs(directory)
        # Save meta_data
        data = {}
        data['meta_data'] = []
        data['meta_data'].append({
            'img shape: height,width,channels': self.img_shape,
            'batch size': self.batch_size,
            'save interval': self.save_interval,
            'normalization function': str(self.normalization),
            'lambda_1': self.lambda_1,
            'lambda_2': self.lambda_2,
            'lambda_d': self.lambda_D,
            'learning_rate_D': self.learning_rate_D,
            'learning rate G': self.learning_rate_G,
            'epochs': self.epochs,
            'use linear decay on learning rates': self.use_linear_decay,
            'use multiscale discriminator': self.use_multiscale_discriminator,
            'epoch where learning rate linear decay is initialized (if use_linear_decay)': self.decay_epoch,
            'generator iterations': self.generator_iterations,
            'discriminator iterations': self.discriminator_iterations,
            'use patchGan in discriminator': self.use_patchgan,
            'beta 1': self.beta_1,
            'beta 2': self.beta_2,
            'REAL_LABEL': self.REAL_LABEL,
            'number of A train examples': len(self.A_train),
            'number of B train examples': len(self.B_train),
            'number of A test examples': len(self.A_test),
            'number of B test examples': len(self.B_test),
        })

        with open('images/{}/meta_data.json'.format(self.date_time), 'w') as outfile:
            json.dump(data, outfile, sort_keys=True)

    def load_model_and_weights(self, model):
        path_to_model = os.path.join('generate_images', 'models', '{}.json'.format(model.name))
        path_to_weights = os.path.join('generate_images', 'models', '{}.hdf5'.format(model.name))
        #model = model_from_json(path_to_model)
        model.load_weights(path_to_weights)

    def load_model_and_generate_synthetic_images(self):
        response = input('Are you sure you want to generate synthetic images instead of training? (y/n): ')[0].lower()
        if response == 'y':
            self.load_model_and_weights(self.G_A2B)
            self.load_model_and_weights(self.G_B2A)
            synthetic_images_B = self.G_A2B.predict(self.A_test)
            synthetic_images_A = self.G_B2A.predict(self.B_test)

            def save_image(image, name, domain):
                if self.channels == 1:
                    image = image[:, :, 0]
                toimage(image, cmin=-1, cmax=1).save(os.path.join(
                    'generate_images', 'synthetic_images', domain, name))

            # Test A images
            for i in range(len(synthetic_images_A)):
                # Get the name from the image it was conditioned on
                name = self.testB_image_names[i].strip('.png') + '_synthetic.png'
                synt_A = synthetic_images_A[i]
                save_image(synt_A, name, 'A')

            # Test B images
            for i in range(len(synthetic_images_B)):
                # Get the name from the image it was conditioned on
                name = self.testA_image_names[i].strip('.png') + '_synthetic.png'
                synt_B = synthetic_images_B[i]
                save_image(synt_B, name, 'B')

            print('{} synthetic images have been generated and placed in ./generate_images/synthetic_images'
                  .format(len(self.A_test) + len(self.B_test)))


# reflection padding taken from
# https://github.com/fastai/courses/blob/master/deeplearning2/neural-style.ipynb
class ReflectionPadding2D(Layer):
    def __init__(self, padding=(1, 1), **kwargs):
        self.padding = tuple(padding)
        self.input_spec = [InputSpec(ndim=4)]
        super(ReflectionPadding2D, self).__init__(**kwargs)

    def compute_output_shape(self, s):
        return (s[0], s[1] + 2 * self.padding[0], s[2] + 2 * self.padding[1], s[3])

    def call(self, x, mask=None):
        w_pad, h_pad = self.padding
        return tf.pad(x, [[0, 0], [h_pad, h_pad], [w_pad, w_pad], [0, 0]], 'REFLECT')


class ImagePool():
    def __init__(self, pool_size):
        self.pool_size = pool_size
        if self.pool_size > 0:
            self.num_imgs = 0
            self.images = []

    def query(self, images):
        if self.pool_size == 0:
            return images
        return_images = []
        for image in images:
            if len(image.shape) == 3:
                image = image[np.newaxis, :, :, :]

            if self.num_imgs < self.pool_size:  # fill up the image pool
                self.num_imgs = self.num_imgs + 1
                if len(self.images) == 0:
                    self.images = image
                else:
                    self.images = np.vstack((self.images, image))

                if len(return_images) == 0:
                    return_images = image
                else:
                    return_images = np.vstack((return_images, image))

            else:  # 50% chance that we replace an old synthetic image
                p = random.uniform(0, 1)
                if p > 0.5:
                    random_id = random.randint(0, self.pool_size - 1)
                    tmp = self.images[random_id, :, :, :]
                    tmp = tmp[np.newaxis, :, :, :]
                    self.images[random_id, :, :, :] = image[0, :, :, :]
                    if len(return_images) == 0:
                        return_images = tmp
                    else:
                        return_images = np.vstack((return_images, tmp))
                else:
                    if len(return_images) == 0:
                        return_images = image
                    else:
                        return_images = np.vstack((return_images, image))

        return return_images


if __name__ == '__main__':
    GAN = CycleGAN()
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# --- Caching data ---
# Data has been loaded
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
#
#
# Epoch---------------- 1 / 100
# Loop index---------------- 1 / 30
# D_loss:  3.1172037
# G_loss:  38.552418
# reconstruction_loss:  21.003496
# dA_loss: 1.3413777
# DB_loss: 1.7758259
# Time passed 0:01:08 : ETA in 236452 days, 19:08:00
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:810: DeprecationWarning:     `toimage` is deprecated!
#     `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use Pillow's ``Image.fromarray`` directly instead.
# Streaming output truncated to the last 5000 lines.
# D_loss:  0.38607013
# G_loss:  2.0488143
# reconstruction_loss:  1.4025608
# dA_loss: 0.33195257
# DB_loss: 0.054117553
#
#
#  -------------------------Saving images for epoch 82 -------------------------
#
#
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 1 / 30
# D_loss:  0.56270105
# G_loss:  2.2884274
# reconstruction_loss:  1.6999505
# dA_loss: 0.26615745
# DB_loss: 0.2965436
# Time passed 0:14:31 : ETA in 0:03:11
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 2 / 30
# D_loss:  0.3289363
# G_loss:  2.3035946
# reconstruction_loss:  1.6707299
# dA_loss: 0.28064936
# DB_loss: 0.048286952
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 3 / 30
# D_loss:  0.60440475
# G_loss:  1.9326751
# reconstruction_loss:  1.3663872
# dA_loss: 0.30556655
# DB_loss: 0.2988382
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 4 / 30
# D_loss:  0.4565885
# G_loss:  2.1476474
# reconstruction_loss:  1.5071661
# dA_loss: 0.32608613
# DB_loss: 0.13050239
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 5 / 30
# D_loss:  0.6125785
# G_loss:  2.1677618
# reconstruction_loss:  1.465365
# dA_loss: 0.36004692
# DB_loss: 0.25253156
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 6 / 30
# D_loss:  0.44476426
# G_loss:  2.4957888
# reconstruction_loss:  1.7676282
# dA_loss: 0.2867075
# DB_loss: 0.15805677
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 7 / 30
# D_loss:  1.1690698
# G_loss:  1.8687745
# reconstruction_loss:  1.18049
# dA_loss: 0.327852
# DB_loss: 0.84121776
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 8 / 30
# D_loss:  0.5712682
# G_loss:  2.0656579
# reconstruction_loss:  1.4141394
# dA_loss: 0.29920548
# DB_loss: 0.27206272
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 9 / 30
# D_loss:  0.63282335
# G_loss:  1.7475132
# reconstruction_loss:  1.1244581
# dA_loss: 0.3242606
# DB_loss: 0.3085628
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 10 / 30
# D_loss:  0.3915817
# G_loss:  2.1522245
# reconstruction_loss:  1.495005
# dA_loss: 0.2517679
# DB_loss: 0.13981381
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 11 / 30
# D_loss:  0.39950553
# G_loss:  2.0043845
# reconstruction_loss:  1.3955522
# dA_loss: 0.3129037
# DB_loss: 0.08660182
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 12 / 30
# D_loss:  0.6554563
# G_loss:  1.9318321
# reconstruction_loss:  1.1932518
# dA_loss: 0.39061978
# DB_loss: 0.26483655
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 13 / 30
# D_loss:  0.4062773
# G_loss:  2.2706537
# reconstruction_loss:  1.5845983
# dA_loss: 0.29367816
# DB_loss: 0.112599134
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 14 / 30
# D_loss:  0.41341507
# G_loss:  1.887624
# reconstruction_loss:  1.2146235
# dA_loss: 0.2792322
# DB_loss: 0.13418287
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 15 / 30
# D_loss:  0.41961002
# G_loss:  2.2654734
# reconstruction_loss:  1.5720004
# dA_loss: 0.30289066
# DB_loss: 0.11671936
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 16 / 30
# D_loss:  0.6460079
# G_loss:  2.1754153
# reconstruction_loss:  1.5022178
# dA_loss: 0.34595507
# DB_loss: 0.30005282
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 17 / 30
# D_loss:  0.50092256
# G_loss:  2.3360696
# reconstruction_loss:  1.5330021
# dA_loss: 0.35131723
# DB_loss: 0.1496053
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 18 / 30
# D_loss:  0.39832497
# G_loss:  2.2507567
# reconstruction_loss:  1.5378305
# dA_loss: 0.31411913
# DB_loss: 0.08420582
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 19 / 30
# D_loss:  0.5177741
# G_loss:  1.8131108
# reconstruction_loss:  1.1165645
# dA_loss: 0.3197052
# DB_loss: 0.19806889
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 20 / 30
# D_loss:  0.6640318
# G_loss:  2.4301784
# reconstruction_loss:  1.8903011
# dA_loss: 0.3041532
# DB_loss: 0.3598786
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 21 / 30
# D_loss:  0.44815272
# G_loss:  2.0818143
# reconstruction_loss:  1.4832437
# dA_loss: 0.3244642
# DB_loss: 0.12368852
# Time passed 0:14:37 : ETA in 0:03:04
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 22 / 30
# D_loss:  0.4605183
# G_loss:  2.1839228
# reconstruction_loss:  1.5341712
# dA_loss: 0.31043267
# DB_loss: 0.15008561
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 23 / 30
# D_loss:  0.45122984
# G_loss:  2.188502
# reconstruction_loss:  1.5435507
# dA_loss: 0.33845964
# DB_loss: 0.1127702
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 24 / 30
# D_loss:  0.6215317
# G_loss:  2.0590124
# reconstruction_loss:  1.4212166
# dA_loss: 0.3090219
# DB_loss: 0.31250983
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 25 / 30
# D_loss:  0.47936603
# G_loss:  2.244267
# reconstruction_loss:  1.5493288
# dA_loss: 0.3239048
# DB_loss: 0.15546122
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 26 / 30
# D_loss:  0.57090086
# G_loss:  2.0480676
# reconstruction_loss:  1.3958435
# dA_loss: 0.37634528
# DB_loss: 0.1945556
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 27 / 30
# D_loss:  0.47968668
# G_loss:  2.2763536
# reconstruction_loss:  1.5497181
# dA_loss: 0.28329727
# DB_loss: 0.19638939
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 28 / 30
# D_loss:  0.35049093
# G_loss:  2.0569665
# reconstruction_loss:  1.4336568
# dA_loss: 0.27933556
# DB_loss: 0.07115536
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 29 / 30
# D_loss:  0.8028075
# G_loss:  1.9367602
# reconstruction_loss:  1.2449328
# dA_loss: 0.340793
# DB_loss: 0.4620145
#
#
# Epoch---------------- 83 / 100
# Loop index---------------- 30 / 30
# D_loss:  0.4034232
# G_loss:  2.2287893
# reconstruction_loss:  1.5349826
# dA_loss: 0.28344947
# DB_loss: 0.119973734
#
#
#  -------------------------Saving images for epoch 83 -------------------------
#
#
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 1 / 30
# D_loss:  0.38014007
# G_loss:  2.074679
# reconstruction_loss:  1.4176313
# dA_loss: 0.29254082
# DB_loss: 0.08759923
# Time passed 0:14:40 : ETA in 0:03:00
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 2 / 30
# D_loss:  0.45372415
# G_loss:  2.1545196
# reconstruction_loss:  1.5806856
# dA_loss: 0.2579131
# DB_loss: 0.19581105
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 3 / 30
# D_loss:  0.3859503
# G_loss:  2.07816
# reconstruction_loss:  1.4137509
# dA_loss: 0.32207245
# DB_loss: 0.06387786
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 4 / 30
# D_loss:  0.42413914
# G_loss:  2.1168177
# reconstruction_loss:  1.285448
# dA_loss: 0.30205142
# DB_loss: 0.12208772
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 5 / 30
# D_loss:  0.3178271
# G_loss:  2.3658638
# reconstruction_loss:  1.6292999
# dA_loss: 0.2624043
# DB_loss: 0.05542281
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 6 / 30
# D_loss:  0.62931865
# G_loss:  2.2230582
# reconstruction_loss:  1.5072851
# dA_loss: 0.28853452
# DB_loss: 0.34078413
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 7 / 30
# D_loss:  0.38828617
# G_loss:  2.0919447
# reconstruction_loss:  1.5209689
# dA_loss: 0.27928478
# DB_loss: 0.10900138
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 8 / 30
# D_loss:  0.32572562
# G_loss:  2.2358289
# reconstruction_loss:  1.6650112
# dA_loss: 0.25033772
# DB_loss: 0.07538791
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 9 / 30
# D_loss:  0.7726065
# G_loss:  2.0325675
# reconstruction_loss:  1.3150995
# dA_loss: 0.2491661
# DB_loss: 0.5234404
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 10 / 30
# D_loss:  0.4987829
# G_loss:  2.169647
# reconstruction_loss:  1.5054092
# dA_loss: 0.3548652
# DB_loss: 0.14391771
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 11 / 30
# D_loss:  0.5000609
# G_loss:  1.9735227
# reconstruction_loss:  1.3220284
# dA_loss: 0.3157611
# DB_loss: 0.18429981
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 12 / 30
# D_loss:  0.44372672
# G_loss:  1.9813478
# reconstruction_loss:  1.3667067
# dA_loss: 0.32207358
# DB_loss: 0.121653154
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 13 / 30
# D_loss:  0.44290102
# G_loss:  2.1826015
# reconstruction_loss:  1.5789793
# dA_loss: 0.2308482
# DB_loss: 0.2120528
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 14 / 30
# D_loss:  0.45006225
# G_loss:  2.0085914
# reconstruction_loss:  1.3766582
# dA_loss: 0.3261726
# DB_loss: 0.12388965
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 15 / 30
# D_loss:  0.49087706
# G_loss:  2.071692
# reconstruction_loss:  1.3584418
# dA_loss: 0.32640445
# DB_loss: 0.16447261
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 16 / 30
# D_loss:  0.46687242
# G_loss:  2.092459
# reconstruction_loss:  1.5283909
# dA_loss: 0.29141468
# DB_loss: 0.17545775
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 17 / 30
# D_loss:  0.5207333
# G_loss:  1.9529905
# reconstruction_loss:  1.2899408
# dA_loss: 0.3069179
# DB_loss: 0.21381539
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 18 / 30
# D_loss:  0.3926298
# G_loss:  2.3855324
# reconstruction_loss:  1.7358177
# dA_loss: 0.283316
# DB_loss: 0.1093138
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 19 / 30
# D_loss:  0.64596283
# G_loss:  1.8649224
# reconstruction_loss:  1.2274548
# dA_loss: 0.2867281
# DB_loss: 0.3592347
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 20 / 30
# D_loss:  0.60360765
# G_loss:  2.0251622
# reconstruction_loss:  1.3658757
# dA_loss: 0.3135403
# DB_loss: 0.29006737
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 21 / 30
# D_loss:  0.55057055
# G_loss:  1.9617658
# reconstruction_loss:  1.3153751
# dA_loss: 0.3269394
# DB_loss: 0.22363114
# Time passed 0:14:46 : ETA in 0:02:53
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 22 / 30
# D_loss:  0.47540444
# G_loss:  2.0819726
# reconstruction_loss:  1.5074787
# dA_loss: 0.3418911
# DB_loss: 0.13351333
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 23 / 30
# D_loss:  0.42890456
# G_loss:  2.096554
# reconstruction_loss:  1.4903157
# dA_loss: 0.26746625
# DB_loss: 0.16143832
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 24 / 30
# D_loss:  0.51729876
# G_loss:  2.1346147
# reconstruction_loss:  1.4483626
# dA_loss: 0.31414747
# DB_loss: 0.20315129
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 25 / 30
# D_loss:  0.52092534
# G_loss:  2.170855
# reconstruction_loss:  1.3451319
# dA_loss: 0.25798613
# DB_loss: 0.2629392
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 26 / 30
# D_loss:  0.38086087
# G_loss:  2.1879082
# reconstruction_loss:  1.4381863
# dA_loss: 0.32244062
# DB_loss: 0.058420256
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 27 / 30
# D_loss:  0.4982698
# G_loss:  2.0104613
# reconstruction_loss:  1.4482092
# dA_loss: 0.3384802
# DB_loss: 0.1597896
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 28 / 30
# D_loss:  0.40392405
# G_loss:  2.2978346
# reconstruction_loss:  1.6248595
# dA_loss: 0.29944772
# DB_loss: 0.10447634
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 29 / 30
# D_loss:  0.35900447
# G_loss:  2.0600352
# reconstruction_loss:  1.3793173
# dA_loss: 0.23943773
# DB_loss: 0.119566746
#
#
# Epoch---------------- 84 / 100
# Loop index---------------- 30 / 30
# D_loss:  0.39839315
# G_loss:  2.2977054
# reconstruction_loss:  1.6381221
# dA_loss: 0.33465707
# DB_loss: 0.06373609
#
#
#  -------------------------Saving images for epoch 84 -------------------------
#
#
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 1 / 30
# D_loss:  0.5848739
# G_loss:  2.0114536
# reconstruction_loss:  1.4384481
# dA_loss: 0.2919776
# DB_loss: 0.29289633
# Time passed 0:14:49 : ETA in 0:02:49
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 2 / 30
# D_loss:  0.39024213
# G_loss:  2.3321643
# reconstruction_loss:  1.5726517
# dA_loss: 0.2669736
# DB_loss: 0.123268515
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 3 / 30
# D_loss:  0.5653367
# G_loss:  1.9370916
# reconstruction_loss:  1.3074423
# dA_loss: 0.33098716
# DB_loss: 0.23434955
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 4 / 30
# D_loss:  0.3951097
# G_loss:  2.1124425
# reconstruction_loss:  1.5319417
# dA_loss: 0.29679084
# DB_loss: 0.09831887
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 5 / 30
# D_loss:  0.38233006
# G_loss:  1.9410186
# reconstruction_loss:  1.3542852
# dA_loss: 0.25953114
# DB_loss: 0.12279893
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 6 / 30
# D_loss:  0.5854461
# G_loss:  1.9596106
# reconstruction_loss:  1.3358977
# dA_loss: 0.3233328
# DB_loss: 0.26211333
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 7 / 30
# D_loss:  0.3921617
# G_loss:  2.13406
# reconstruction_loss:  1.5033916
# dA_loss: 0.2977368
# DB_loss: 0.094424896
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 8 / 30
# D_loss:  0.46418864
# G_loss:  2.2382636
# reconstruction_loss:  1.5773534
# dA_loss: 0.29091543
# DB_loss: 0.17327322
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 9 / 30
# D_loss:  0.45970422
# G_loss:  2.5612774
# reconstruction_loss:  1.9354815
# dA_loss: 0.2546618
# DB_loss: 0.20504242
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 10 / 30
# D_loss:  0.8583323
# G_loss:  1.9094437
# reconstruction_loss:  1.1419256
# dA_loss: 0.3114376
# DB_loss: 0.54689467
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 11 / 30
# D_loss:  0.40669912
# G_loss:  2.201572
# reconstruction_loss:  1.499814
# dA_loss: 0.29098827
# DB_loss: 0.11571084
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 12 / 30
# D_loss:  0.44271037
# G_loss:  2.2344172
# reconstruction_loss:  1.4636587
# dA_loss: 0.29595613
# DB_loss: 0.14675424
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 13 / 30
# D_loss:  0.4885534
# G_loss:  2.198335
# reconstruction_loss:  1.6236787
# dA_loss: 0.3214601
# DB_loss: 0.16709332
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 14 / 30
# D_loss:  0.2913855
# G_loss:  2.2542017
# reconstruction_loss:  1.6343035
# dA_loss: 0.21817686
# DB_loss: 0.073208645
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 15 / 30
# D_loss:  0.53410685
# G_loss:  2.2208889
# reconstruction_loss:  1.612284
# dA_loss: 0.30514073
# DB_loss: 0.22896613
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 16 / 30
# D_loss:  0.605319
# G_loss:  2.0909355
# reconstruction_loss:  1.3131905
# dA_loss: 0.33118597
# DB_loss: 0.27413306
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 17 / 30
# D_loss:  0.32098812
# G_loss:  2.0395927
# reconstruction_loss:  1.4368196
# dA_loss: 0.2734126
# DB_loss: 0.04757553
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 18 / 30
# D_loss:  0.43865833
# G_loss:  2.2381918
# reconstruction_loss:  1.4472239
# dA_loss: 0.3277892
# DB_loss: 0.11086915
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 19 / 30
# D_loss:  0.33519113
# G_loss:  2.1043408
# reconstruction_loss:  1.4894633
# dA_loss: 0.21000017
# DB_loss: 0.12519097
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 20 / 30
# D_loss:  0.8956951
# G_loss:  2.3420467
# reconstruction_loss:  1.6732767
# dA_loss: 0.43564022
# DB_loss: 0.46005484
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 21 / 30
# D_loss:  0.46033663
# G_loss:  2.1337936
# reconstruction_loss:  1.4505306
# dA_loss: 0.3507817
# DB_loss: 0.10955492
# Time passed 0:14:55 : ETA in 0:02:42
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 22 / 30
# D_loss:  0.40817606
# G_loss:  2.4628515
# reconstruction_loss:  1.5674746
# dA_loss: 0.32057714
# DB_loss: 0.087598935
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 23 / 30
# D_loss:  0.5021066
# G_loss:  2.3064947
# reconstruction_loss:  1.4070884
# dA_loss: 0.3037768
# DB_loss: 0.19832979
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 24 / 30
# D_loss:  0.39967915
# G_loss:  2.4548357
# reconstruction_loss:  1.5269116
# dA_loss: 0.34729022
# DB_loss: 0.052388925
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 25 / 30
# D_loss:  0.8901353
# G_loss:  2.3203743
# reconstruction_loss:  1.583248
# dA_loss: 0.32005632
# DB_loss: 0.57007897
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 26 / 30
# D_loss:  0.50523937
# G_loss:  2.2582278
# reconstruction_loss:  1.4823904
# dA_loss: 0.27335805
# DB_loss: 0.23188134
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 27 / 30
# D_loss:  0.4789882
# G_loss:  2.108234
# reconstruction_loss:  1.4649876
# dA_loss: 0.30408302
# DB_loss: 0.17490518
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 28 / 30
# D_loss:  0.42431736
# G_loss:  2.308197
# reconstruction_loss:  1.5408523
# dA_loss: 0.29604656
# DB_loss: 0.1282708
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 29 / 30
# D_loss:  0.51365757
# G_loss:  2.153202
# reconstruction_loss:  1.480389
# dA_loss: 0.31695488
# DB_loss: 0.19670266
#
#
# Epoch---------------- 85 / 100
# Loop index---------------- 30 / 30
# D_loss:  0.36284512
# G_loss:  2.2765727
# reconstruction_loss:  1.6062524
# dA_loss: 0.268103
# DB_loss: 0.094742104
#
#
#  -------------------------Saving images for epoch 85 -------------------------
#
#
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 1 / 30
# D_loss:  0.7109255
# G_loss:  1.8148961
# reconstruction_loss:  1.2202697
# dA_loss: 0.2747047
# DB_loss: 0.43622082
# Time passed 0:14:58 : ETA in 0:02:39
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 2 / 30
# D_loss:  0.3827014
# G_loss:  2.2728238
# reconstruction_loss:  1.5873158
# dA_loss: 0.2926529
# DB_loss: 0.09004848
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 3 / 30
# D_loss:  0.3914252
# G_loss:  2.149208
# reconstruction_loss:  1.5350277
# dA_loss: 0.25796068
# DB_loss: 0.1334645
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 4 / 30
# D_loss:  0.47178626
# G_loss:  1.9371343
# reconstruction_loss:  1.27545
# dA_loss: 0.31841987
# DB_loss: 0.15336637
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 5 / 30
# D_loss:  0.42853913
# G_loss:  2.2313066
# reconstruction_loss:  1.5997598
# dA_loss: 0.33420336
# DB_loss: 0.094335765
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 6 / 30
# D_loss:  0.47059357
# G_loss:  2.023484
# reconstruction_loss:  1.3285422
# dA_loss: 0.2731225
# DB_loss: 0.19747108
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 7 / 30
# D_loss:  0.40594646
# G_loss:  1.9980497
# reconstruction_loss:  1.3932682
# dA_loss: 0.3077033
# DB_loss: 0.09824318
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 8 / 30
# D_loss:  0.32069385
# G_loss:  2.0414853
# reconstruction_loss:  1.5098875
# dA_loss: 0.20822707
# DB_loss: 0.1124668
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 9 / 30
# D_loss:  0.44495705
# G_loss:  2.102565
# reconstruction_loss:  1.4708593
# dA_loss: 0.28689384
# DB_loss: 0.1580632
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 10 / 30
# D_loss:  0.5496361
# G_loss:  1.9871011
# reconstruction_loss:  1.3112335
# dA_loss: 0.31955197
# DB_loss: 0.23008417
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 11 / 30
# D_loss:  0.41446298
# G_loss:  2.37473
# reconstruction_loss:  1.6914061
# dA_loss: 0.3007204
# DB_loss: 0.113742575
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 12 / 30
# D_loss:  0.46186447
# G_loss:  2.1337497
# reconstruction_loss:  1.4301902
# dA_loss: 0.21535751
# DB_loss: 0.24650696
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 13 / 30
# D_loss:  0.39400688
# G_loss:  2.2129278
# reconstruction_loss:  1.5403079
# dA_loss: 0.299492
# DB_loss: 0.094514884
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 14 / 30
# D_loss:  0.4263007
# G_loss:  2.3846035
# reconstruction_loss:  1.7441483
# dA_loss: 0.25507578
# DB_loss: 0.1712249
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 15 / 30
# D_loss:  0.6164079
# G_loss:  2.0664
# reconstruction_loss:  1.4049363
# dA_loss: 0.26986885
# DB_loss: 0.34653902
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 16 / 30
# D_loss:  0.34209353
# G_loss:  2.18266
# reconstruction_loss:  1.6273342
# dA_loss: 0.23587534
# DB_loss: 0.10621819
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 17 / 30
# D_loss:  0.3208293
# G_loss:  2.0921092
# reconstruction_loss:  1.5221916
# dA_loss: 0.22431177
# DB_loss: 0.09651753
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 18 / 30
# D_loss:  0.5040373
# G_loss:  2.0532522
# reconstruction_loss:  1.4036876
# dA_loss: 0.40726435
# DB_loss: 0.09677298
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 19 / 30
# D_loss:  0.30355164
# G_loss:  2.2598906
# reconstruction_loss:  1.5977342
# dA_loss: 0.24788564
# DB_loss: 0.055665992
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 20 / 30
# D_loss:  0.66851425
# G_loss:  2.1627262
# reconstruction_loss:  1.4857874
# dA_loss: 0.34730837
# DB_loss: 0.32120585
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 21 / 30
# D_loss:  0.36939692
# G_loss:  2.194291
# reconstruction_loss:  1.4449973
# dA_loss: 0.24999192
# DB_loss: 0.11940502
# Time passed 0:15:04 : ETA in 0:02:31
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 22 / 30
# D_loss:  0.3491271
# G_loss:  2.261309
# reconstruction_loss:  1.6275425
# dA_loss: 0.2758558
# DB_loss: 0.07327132
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 23 / 30
# D_loss:  0.533447
# G_loss:  1.974973
# reconstruction_loss:  1.3301818
# dA_loss: 0.36019117
# DB_loss: 0.17325586
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 24 / 30
# D_loss:  0.48528185
# G_loss:  2.076487
# reconstruction_loss:  1.4939907
# dA_loss: 0.2587492
# DB_loss: 0.22653267
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 25 / 30
# D_loss:  0.4384585
# G_loss:  2.069631
# reconstruction_loss:  1.3921087
# dA_loss: 0.35092205
# DB_loss: 0.087536454
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 26 / 30
# D_loss:  0.43442544
# G_loss:  2.2201896
# reconstruction_loss:  1.5503652
# dA_loss: 0.30822128
# DB_loss: 0.12620416
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 27 / 30
# D_loss:  0.3791714
# G_loss:  2.1690612
# reconstruction_loss:  1.5166361
# dA_loss: 0.2409232
# DB_loss: 0.1382482
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 28 / 30
# D_loss:  0.31211868
# G_loss:  2.24755
# reconstruction_loss:  1.5901346
# dA_loss: 0.2543164
# DB_loss: 0.057802282
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 29 / 30
# D_loss:  0.39054093
# G_loss:  2.2761576
# reconstruction_loss:  1.5276992
# dA_loss: 0.24288285
# DB_loss: 0.14765808
#
#
# Epoch---------------- 86 / 100
# Loop index---------------- 30 / 30
# D_loss:  0.49156594
# G_loss:  2.6321697
# reconstruction_loss:  1.8757485
# dA_loss: 0.30319294
# DB_loss: 0.188373
#
#
#  -------------------------Saving images for epoch 86 -------------------------
#
#
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 1 / 30
# D_loss:  0.48747146
# G_loss:  1.9686515
# reconstruction_loss:  1.2639556
# dA_loss: 0.32293352
# DB_loss: 0.16453794
# Time passed 0:15:08 : ETA in 0:02:28
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 2 / 30
# D_loss:  0.69756967
# G_loss:  2.3928883
# reconstruction_loss:  1.7907314
# dA_loss: 0.26082578
# DB_loss: 0.4367439
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 3 / 30
# D_loss:  0.4571526
# G_loss:  2.059027
# reconstruction_loss:  1.3805034
# dA_loss: 0.2616024
# DB_loss: 0.1955502
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 4 / 30
# D_loss:  0.5631825
# G_loss:  2.1365368
# reconstruction_loss:  1.4903417
# dA_loss: 0.26465622
# DB_loss: 0.29852623
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 5 / 30
# D_loss:  0.408969
# G_loss:  2.3222501
# reconstruction_loss:  1.65775
# dA_loss: 0.2773375
# DB_loss: 0.13163152
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 6 / 30
# D_loss:  0.5824386
# G_loss:  1.9904776
# reconstruction_loss:  1.3668753
# dA_loss: 0.37152702
# DB_loss: 0.21091154
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 7 / 30
# D_loss:  0.39574808
# G_loss:  2.4601135
# reconstruction_loss:  1.7903281
# dA_loss: 0.25381175
# DB_loss: 0.14193633
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 8 / 30
# D_loss:  0.3354628
# G_loss:  2.3897097
# reconstruction_loss:  1.7229482
# dA_loss: 0.24480864
# DB_loss: 0.090654165
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 9 / 30
# D_loss:  0.5638919
# G_loss:  2.4532633
# reconstruction_loss:  1.835629
# dA_loss: 0.38744548
# DB_loss: 0.17644644
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 10 / 30
# D_loss:  0.8603589
# G_loss:  2.1754866
# reconstruction_loss:  1.4088535
# dA_loss: 0.35562748
# DB_loss: 0.5047314
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 11 / 30
# D_loss:  0.40777743
# G_loss:  2.4954004
# reconstruction_loss:  1.8201115
# dA_loss: 0.3065315
# DB_loss: 0.10124595
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 12 / 30
# D_loss:  0.7375691
# G_loss:  1.9828668
# reconstruction_loss:  1.2575254
# dA_loss: 0.30097166
# DB_loss: 0.43659744
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 13 / 30
# D_loss:  0.6152292
# G_loss:  2.0438967
# reconstruction_loss:  1.2836002
# dA_loss: 0.28760928
# DB_loss: 0.3276199
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 14 / 30
# D_loss:  0.47211695
# G_loss:  2.422236
# reconstruction_loss:  1.6122686
# dA_loss: 0.2805496
# DB_loss: 0.19156738
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 15 / 30
# D_loss:  0.48083878
# G_loss:  2.1771889
# reconstruction_loss:  1.436689
# dA_loss: 0.29815805
# DB_loss: 0.18268074
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 16 / 30
# D_loss:  0.39762396
# G_loss:  1.9756005
# reconstruction_loss:  1.3152099
# dA_loss: 0.28997105
# DB_loss: 0.107652895
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 17 / 30
# D_loss:  0.42255187
# G_loss:  2.520553
# reconstruction_loss:  1.7427645
# dA_loss: 0.24905252
# DB_loss: 0.17349936
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 18 / 30
# D_loss:  0.46968186
# G_loss:  2.0125256
# reconstruction_loss:  1.3500713
# dA_loss: 0.2625459
# DB_loss: 0.20713595
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 19 / 30
# D_loss:  0.41364574
# G_loss:  2.0790176
# reconstruction_loss:  1.5224025
# dA_loss: 0.28884846
# DB_loss: 0.12479728
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 20 / 30
# D_loss:  0.4648919
# G_loss:  2.3054585
# reconstruction_loss:  1.6329389
# dA_loss: 0.23374149
# DB_loss: 0.23115042
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 21 / 30
# D_loss:  0.625844
# G_loss:  2.2783718
# reconstruction_loss:  1.5621686
# dA_loss: 0.24046284
# DB_loss: 0.3853812
# Time passed 0:15:14 : ETA in 0:02:21
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 22 / 30
# D_loss:  0.33682817
# G_loss:  2.2579541
# reconstruction_loss:  1.5408902
# dA_loss: 0.21525413
# DB_loss: 0.12157403
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 23 / 30
# D_loss:  0.4640165
# G_loss:  2.042619
# reconstruction_loss:  1.344163
# dA_loss: 0.30430463
# DB_loss: 0.15971188
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 24 / 30
# D_loss:  0.4717227
# G_loss:  2.4588616
# reconstruction_loss:  1.8052046
# dA_loss: 0.3446978
# DB_loss: 0.12702489
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 25 / 30
# D_loss:  0.4192257
# G_loss:  2.1564782
# reconstruction_loss:  1.4874346
# dA_loss: 0.27381736
# DB_loss: 0.14540835
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 26 / 30
# D_loss:  0.46139547
# G_loss:  2.0701895
# reconstruction_loss:  1.3876464
# dA_loss: 0.31220156
# DB_loss: 0.14919391
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 27 / 30
# D_loss:  0.37114707
# G_loss:  2.103288
# reconstruction_loss:  1.387042
# dA_loss: 0.26409495
# DB_loss: 0.10705211
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 28 / 30
# D_loss:  0.39114603
# G_loss:  2.0848598
# reconstruction_loss:  1.4383292
# dA_loss: 0.28679916
# DB_loss: 0.104346864
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 29 / 30
# D_loss:  0.36357248
# G_loss:  2.0979853
# reconstruction_loss:  1.4889157
# dA_loss: 0.24781927
# DB_loss: 0.11575319
#
#
# Epoch---------------- 87 / 100
# Loop index---------------- 30 / 30
# D_loss:  0.3407972
# G_loss:  2.4774
# reconstruction_loss:  1.556988
# dA_loss: 0.3015312
# DB_loss: 0.039266005
#
#
#  -------------------------Saving images for epoch 87 -------------------------
#
#
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 1 / 30
# D_loss:  0.5651506
# G_loss:  2.3186631
# reconstruction_loss:  1.5874349
# dA_loss: 0.3111301
# DB_loss: 0.25402054
# Time passed 0:15:17 : ETA in 0:02:17
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 2 / 30
# D_loss:  0.4969392
# G_loss:  2.1529253
# reconstruction_loss:  1.4350119
# dA_loss: 0.24691242
# DB_loss: 0.2500268
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 3 / 30
# D_loss:  0.4338327
# G_loss:  2.5843184
# reconstruction_loss:  1.8841767
# dA_loss: 0.33136964
# DB_loss: 0.102463074
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 4 / 30
# D_loss:  0.36104178
# G_loss:  2.1676564
# reconstruction_loss:  1.5072238
# dA_loss: 0.2328586
# DB_loss: 0.12818317
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 5 / 30
# D_loss:  0.3260485
# G_loss:  2.3384097
# reconstruction_loss:  1.6045489
# dA_loss: 0.28489447
# DB_loss: 0.041154012
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 6 / 30
# D_loss:  0.6743057
# G_loss:  2.2156372
# reconstruction_loss:  1.5435553
# dA_loss: 0.32178798
# DB_loss: 0.35251766
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 7 / 30
# D_loss:  0.3594417
# G_loss:  2.2935538
# reconstruction_loss:  1.7268037
# dA_loss: 0.25355712
# DB_loss: 0.1058846
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 8 / 30
# D_loss:  0.47802132
# G_loss:  2.1348808
# reconstruction_loss:  1.3397514
# dA_loss: 0.31075102
# DB_loss: 0.16727032
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 9 / 30
# D_loss:  0.40878937
# G_loss:  2.358296
# reconstruction_loss:  1.6685807
# dA_loss: 0.30084085
# DB_loss: 0.107948504
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 10 / 30
# D_loss:  0.4672866
# G_loss:  2.4517205
# reconstruction_loss:  1.6668531
# dA_loss: 0.2881379
# DB_loss: 0.17914867
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 11 / 30
# D_loss:  0.5330117
# G_loss:  2.0358043
# reconstruction_loss:  1.3516313
# dA_loss: 0.29081357
# DB_loss: 0.24219814
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 12 / 30
# D_loss:  0.30352142
# G_loss:  2.3484645
# reconstruction_loss:  1.5780997
# dA_loss: 0.2534331
# DB_loss: 0.050088324
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 13 / 30
# D_loss:  0.48451477
# G_loss:  2.1895409
# reconstruction_loss:  1.4959757
# dA_loss: 0.2981326
# DB_loss: 0.18638217
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 14 / 30
# D_loss:  0.4883897
# G_loss:  3.0618134
# reconstruction_loss:  2.2891145
# dA_loss: 0.22004008
# DB_loss: 0.26834962
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 15 / 30
# D_loss:  0.54368937
# G_loss:  1.9259601
# reconstruction_loss:  1.2659128
# dA_loss: 0.31437117
# DB_loss: 0.2293182
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 16 / 30
# D_loss:  0.29503763
# G_loss:  2.1317444
# reconstruction_loss:  1.4772639
# dA_loss: 0.22066677
# DB_loss: 0.074370846
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 17 / 30
# D_loss:  0.37190562
# G_loss:  2.053176
# reconstruction_loss:  1.3846855
# dA_loss: 0.29874927
# DB_loss: 0.07315634
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 18 / 30
# D_loss:  0.36951852
# G_loss:  2.4710712
# reconstruction_loss:  1.8553519
# dA_loss: 0.2535052
# DB_loss: 0.1160133
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 19 / 30
# D_loss:  0.58586204
# G_loss:  2.1263041
# reconstruction_loss:  1.3450437
# dA_loss: 0.29034975
# DB_loss: 0.29551232
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 20 / 30
# D_loss:  0.65342116
# G_loss:  2.1565785
# reconstruction_loss:  1.5171003
# dA_loss: 0.24779154
# DB_loss: 0.4056296
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 21 / 30
# D_loss:  0.48624843
# G_loss:  2.3477912
# reconstruction_loss:  1.6941328
# dA_loss: 0.35725617
# DB_loss: 0.12899226
# Time passed 0:15:23 : ETA in 0:02:10
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 22 / 30
# D_loss:  0.7370225
# G_loss:  1.8796264
# reconstruction_loss:  1.2506454
# dA_loss: 0.30409646
# DB_loss: 0.4329261
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 23 / 30
# D_loss:  0.3405804
# G_loss:  2.0877733
# reconstruction_loss:  1.4341561
# dA_loss: 0.2637098
# DB_loss: 0.076870576
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 24 / 30
# D_loss:  0.5292263
# G_loss:  2.4458978
# reconstruction_loss:  1.6731787
# dA_loss: 0.27299368
# DB_loss: 0.25623262
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 25 / 30
# D_loss:  0.42065972
# G_loss:  2.0893607
# reconstruction_loss:  1.4475307
# dA_loss: 0.27770644
# DB_loss: 0.14295328
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 26 / 30
# D_loss:  0.38358116
# G_loss:  2.3259425
# reconstruction_loss:  1.6148539
# dA_loss: 0.2335366
# DB_loss: 0.15004455
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 27 / 30
# D_loss:  0.48068434
# G_loss:  2.0898235
# reconstruction_loss:  1.4269212
# dA_loss: 0.3269475
# DB_loss: 0.15373681
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 28 / 30
# D_loss:  0.42110947
# G_loss:  2.3296099
# reconstruction_loss:  1.6440778
# dA_loss: 0.28120118
# DB_loss: 0.13990828
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 29 / 30
# D_loss:  0.35263455
# G_loss:  2.166881
# reconstruction_loss:  1.4812913
# dA_loss: 0.29975235
# DB_loss: 0.05288221
#
#
# Epoch---------------- 88 / 100
# Loop index---------------- 30 / 30
# D_loss:  0.32335857
# G_loss:  2.321674
# reconstruction_loss:  1.5465114
# dA_loss: 0.27878726
# DB_loss: 0.04457131
#
#
#  -------------------------Saving images for epoch 88 -------------------------
#
#
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 1 / 30
# D_loss:  0.29423892
# G_loss:  2.135972
# reconstruction_loss:  1.4680336
# dA_loss: 0.25930294
# DB_loss: 0.034935977
# Time passed 0:15:26 : ETA in 0:02:06
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 2 / 30
# D_loss:  0.36110544
# G_loss:  2.2166924
# reconstruction_loss:  1.5116346
# dA_loss: 0.2871195
# DB_loss: 0.07398594
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 3 / 30
# D_loss:  0.33715054
# G_loss:  2.1994922
# reconstruction_loss:  1.5873954
# dA_loss: 0.295315
# DB_loss: 0.041835546
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 4 / 30
# D_loss:  0.5570089
# G_loss:  2.2740903
# reconstruction_loss:  1.554264
# dA_loss: 0.33420038
# DB_loss: 0.22280854
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 5 / 30
# D_loss:  0.3623621
# G_loss:  2.349804
# reconstruction_loss:  1.7832705
# dA_loss: 0.30204642
# DB_loss: 0.060315665
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 6 / 30
# D_loss:  0.510895
# G_loss:  2.1111596
# reconstruction_loss:  1.420492
# dA_loss: 0.26337218
# DB_loss: 0.24752286
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 7 / 30
# D_loss:  0.30333927
# G_loss:  2.2899737
# reconstruction_loss:  1.531411
# dA_loss: 0.2786199
# DB_loss: 0.024719398
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 8 / 30
# D_loss:  0.3322481
# G_loss:  2.1116447
# reconstruction_loss:  1.434057
# dA_loss: 0.21814343
# DB_loss: 0.11410465
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 9 / 30
# D_loss:  0.25387773
# G_loss:  2.2995148
# reconstruction_loss:  1.6618422
# dA_loss: 0.2146641
# DB_loss: 0.039213635
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 10 / 30
# D_loss:  0.6614065
# G_loss:  2.1390958
# reconstruction_loss:  1.4032755
# dA_loss: 0.33307838
# DB_loss: 0.32832813
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 11 / 30
# D_loss:  0.3968626
# G_loss:  2.0678985
# reconstruction_loss:  1.3867044
# dA_loss: 0.29406697
# DB_loss: 0.10279563
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 12 / 30
# D_loss:  0.31860536
# G_loss:  2.311717
# reconstruction_loss:  1.6272128
# dA_loss: 0.28209186
# DB_loss: 0.036513507
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 13 / 30
# D_loss:  0.3221089
# G_loss:  2.2551794
# reconstruction_loss:  1.584964
# dA_loss: 0.24252005
# DB_loss: 0.079588845
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 14 / 30
# D_loss:  0.4771896
# G_loss:  1.8892925
# reconstruction_loss:  1.2713044
# dA_loss: 0.39158702
# DB_loss: 0.08560258
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 15 / 30
# D_loss:  0.38312724
# G_loss:  2.205843
# reconstruction_loss:  1.5369842
# dA_loss: 0.28245977
# DB_loss: 0.10066748
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 16 / 30
# D_loss:  0.44115207
# G_loss:  2.2705655
# reconstruction_loss:  1.5462201
# dA_loss: 0.23087662
# DB_loss: 0.21027544
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 17 / 30
# D_loss:  0.32820243
# G_loss:  2.4259453
# reconstruction_loss:  1.7504029
# dA_loss: 0.2051855
# DB_loss: 0.123016916
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 18 / 30
# D_loss:  0.5052701
# G_loss:  1.9625373
# reconstruction_loss:  1.3512182
# dA_loss: 0.30104727
# DB_loss: 0.20422283
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 19 / 30
# D_loss:  0.4043203
# G_loss:  2.4240203
# reconstruction_loss:  1.8464732
# dA_loss: 0.2970908
# DB_loss: 0.107229516
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 20 / 30
# D_loss:  0.6420259
# G_loss:  2.2322674
# reconstruction_loss:  1.4635558
# dA_loss: 0.32753152
# DB_loss: 0.31449437
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 21 / 30
# D_loss:  0.3515095
# G_loss:  2.2526698
# reconstruction_loss:  1.5266907
# dA_loss: 0.24390143
# DB_loss: 0.107608095
# Time passed 0:15:32 : ETA in 0:01:59
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 22 / 30
# D_loss:  0.43471724
# G_loss:  2.2866266
# reconstruction_loss:  1.574658
# dA_loss: 0.27098256
# DB_loss: 0.16373466
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 23 / 30
# D_loss:  0.3486737
# G_loss:  2.5234132
# reconstruction_loss:  1.7087632
# dA_loss: 0.28958374
# DB_loss: 0.05908997
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 24 / 30
# D_loss:  0.45233458
# G_loss:  2.2982926
# reconstruction_loss:  1.6005814
# dA_loss: 0.25991014
# DB_loss: 0.19242445
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 25 / 30
# D_loss:  0.4433421
# G_loss:  2.6147256
# reconstruction_loss:  1.9393622
# dA_loss: 0.2670402
# DB_loss: 0.17630191
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 26 / 30
# D_loss:  0.64112043
# G_loss:  2.0987573
# reconstruction_loss:  1.3786005
# dA_loss: 0.22907558
# DB_loss: 0.41204482
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 27 / 30
# D_loss:  0.38258514
# G_loss:  2.0419443
# reconstruction_loss:  1.384536
# dA_loss: 0.2632448
# DB_loss: 0.11934032
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 28 / 30
# D_loss:  0.42472973
# G_loss:  2.328896
# reconstruction_loss:  1.6658635
# dA_loss: 0.31140417
# DB_loss: 0.113325566
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 29 / 30
# D_loss:  0.39040262
# G_loss:  1.9386332
# reconstruction_loss:  1.2861031
# dA_loss: 0.2847187
# DB_loss: 0.10568394
#
#
# Epoch---------------- 89 / 100
# Loop index---------------- 30 / 30
# D_loss:  0.26699775
# G_loss:  2.279895
# reconstruction_loss:  1.6998898
# dA_loss: 0.19070193
# DB_loss: 0.07629582
#
#
#  -------------------------Saving images for epoch 89 -------------------------
#
#
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 1 / 30
# D_loss:  0.44694796
# G_loss:  2.2299023
# reconstruction_loss:  1.5397899
# dA_loss: 0.3492267
# DB_loss: 0.09772125
# Time passed 0:15:35 : ETA in 0:01:56
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 2 / 30
# D_loss:  0.3502678
# G_loss:  2.196837
# reconstruction_loss:  1.5274494
# dA_loss: 0.25672758
# DB_loss: 0.09354022
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 3 / 30
# D_loss:  0.49133718
# G_loss:  2.3991983
# reconstruction_loss:  1.5021718
# dA_loss: 0.28584856
# DB_loss: 0.20548862
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 4 / 30
# D_loss:  0.54477525
# G_loss:  2.53541
# reconstruction_loss:  1.7721521
# dA_loss: 0.24316055
# DB_loss: 0.3016147
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 5 / 30
# D_loss:  0.62231386
# G_loss:  1.9429183
# reconstruction_loss:  1.2679107
# dA_loss: 0.23714891
# DB_loss: 0.38516495
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 6 / 30
# D_loss:  0.4021138
# G_loss:  2.2855194
# reconstruction_loss:  1.5855031
# dA_loss: 0.28109264
# DB_loss: 0.12102117
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 7 / 30
# D_loss:  0.52660406
# G_loss:  2.3332598
# reconstruction_loss:  1.6087475
# dA_loss: 0.3582639
# DB_loss: 0.16834015
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 8 / 30
# D_loss:  0.6064451
# G_loss:  1.97537
# reconstruction_loss:  1.2756568
# dA_loss: 0.28347003
# DB_loss: 0.322975
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 9 / 30
# D_loss:  0.35067052
# G_loss:  2.5538824
# reconstruction_loss:  1.9405766
# dA_loss: 0.2547291
# DB_loss: 0.095941424
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 10 / 30
# D_loss:  0.5065595
# G_loss:  1.9031422
# reconstruction_loss:  1.2919571
# dA_loss: 0.23369727
# DB_loss: 0.27286226
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 11 / 30
# D_loss:  0.4406716
# G_loss:  2.02577
# reconstruction_loss:  1.2907364
# dA_loss: 0.3258809
# DB_loss: 0.11479071
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 12 / 30
# D_loss:  0.39998478
# G_loss:  2.3840914
# reconstruction_loss:  1.7128942
# dA_loss: 0.2544059
# DB_loss: 0.1455789
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 13 / 30
# D_loss:  0.3603044
# G_loss:  2.3199291
# reconstruction_loss:  1.546407
# dA_loss: 0.3122492
# DB_loss: 0.04805517
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 14 / 30
# D_loss:  0.435119
# G_loss:  2.1671712
# reconstruction_loss:  1.4269835
# dA_loss: 0.31180742
# DB_loss: 0.12331158
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 15 / 30
# D_loss:  0.52897006
# G_loss:  2.3605645
# reconstruction_loss:  1.7269609
# dA_loss: 0.2608763
# DB_loss: 0.26809376
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 16 / 30
# D_loss:  0.31416705
# G_loss:  2.2318735
# reconstruction_loss:  1.6216415
# dA_loss: 0.2562095
# DB_loss: 0.057957556
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 17 / 30
# D_loss:  0.6955561
# G_loss:  2.0685482
# reconstruction_loss:  1.3947803
# dA_loss: 0.24673207
# DB_loss: 0.44882405
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 18 / 30
# D_loss:  0.55705065
# G_loss:  2.1420355
# reconstruction_loss:  1.2469188
# dA_loss: 0.33277225
# DB_loss: 0.2242784
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 19 / 30
# D_loss:  0.49298084
# G_loss:  2.5441618
# reconstruction_loss:  1.8588784
# dA_loss: 0.24097481
# DB_loss: 0.25200602
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 20 / 30
# D_loss:  0.40627444
# G_loss:  2.0979037
# reconstruction_loss:  1.4735005
# dA_loss: 0.19026205
# DB_loss: 0.2160124
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 21 / 30
# D_loss:  0.39430988
# G_loss:  2.1402996
# reconstruction_loss:  1.5721375
# dA_loss: 0.24477798
# DB_loss: 0.1495319
# Time passed 0:15:41 : ETA in 0:01:48
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 22 / 30
# D_loss:  0.74940753
# G_loss:  1.8981318
# reconstruction_loss:  1.0824428
# dA_loss: 0.33105022
# DB_loss: 0.4183573
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 23 / 30
# D_loss:  0.41062018
# G_loss:  2.0701776
# reconstruction_loss:  1.4339495
# dA_loss: 0.30031002
# DB_loss: 0.11031016
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 24 / 30
# D_loss:  0.3575824
# G_loss:  2.2651775
# reconstruction_loss:  1.5198869
# dA_loss: 0.22964284
# DB_loss: 0.12793955
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 25 / 30
# D_loss:  0.35701782
# G_loss:  2.163034
# reconstruction_loss:  1.5183632
# dA_loss: 0.26517624
# DB_loss: 0.09184156
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 26 / 30
# D_loss:  0.4467093
# G_loss:  2.415782
# reconstruction_loss:  1.8284683
# dA_loss: 0.19093654
# DB_loss: 0.25577277
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 27 / 30
# D_loss:  0.5903354
# G_loss:  2.2119517
# reconstruction_loss:  1.6289766
# dA_loss: 0.2588082
# DB_loss: 0.33152723
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 28 / 30
# D_loss:  0.42954537
# G_loss:  2.2704659
# reconstruction_loss:  1.6131506
# dA_loss: 0.33251542
# DB_loss: 0.09702995
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 29 / 30
# D_loss:  0.5383084
# G_loss:  2.0185132
# reconstruction_loss:  1.4307504
# dA_loss: 0.37858188
# DB_loss: 0.15972649
#
#
# Epoch---------------- 90 / 100
# Loop index---------------- 30 / 30
# D_loss:  0.44703928
# G_loss:  2.1957211
# reconstruction_loss:  1.455547
# dA_loss: 0.26454407
# DB_loss: 0.1824952
#
#
#  -------------------------Saving images for epoch 90 -------------------------
#
#
#
#
# Epoch---------------- 91 / 100
# Loop index---------------- 1 / 30
# D_loss:  0.40547708
# G_loss:  2.1689396
# reconstruction_loss:  1.5024365
# dA_loss: 0.26342267
# DB_loss: 0.14205441
# Time passed 0:15:44 : ETA in 0:01:45
#
#
# Epoch---------------- 91 / 100
# Loop index---------------- 2 / 30
# D_loss:  0.36900473
# G_loss:  2.2084982
# reconstruction_loss:  1.6255774
# dA_loss: 0.29219562
# DB_loss: 0.07680912
#
#
# Epoch---------------- 91 / 100
# Loop index---------------- 3 / 30
# D_loss:  0.8378648
# G_loss:  1.9414308
# reconstruction_loss:  1.335279
# dA_loss: 0.15226126
# DB_loss: 0.68560356
#
#
# Epoch---------------- 91 / 100
# Loop index---------------- 4 / 30
# D_loss:  0.48241603
# G_loss:  1.9612554
# reconstruction_loss:  1.3778379
# dA_loss: 0.32745588
# DB_loss: 0.15496014
#
#
# Epoch---------------- 91 / 100
# Loop index---------------- 5 / 30
# D_loss:  0.41434905
# G_loss:  2.1273932
# reconstruction_loss:  1.4275941
# dA_loss: 0.3521747
# DB_loss: 0.062174343
#
#
# Epoch---------------- 91 / 100
# Loop index---------------- 6 / 30
# D_loss:  0.5581964
# G_loss:  1.8086675
# reconstruction_loss:  1.225024
# dA_loss: 0.28245628
# DB_loss: 0.27574012
#
#
# Epoch---------------- 91 / 100
# Loop index---------------- 7 / 30
# D_loss:  0.48358452
# G_loss:  2.4858382
# reconstruction_loss:  1.8872395
# dA_loss: 0.28787673
# DB_loss: 0.19570778
#
#
# Epoch---------------- 91 / 100
# Loop index---------------- 8 / 30
# D_loss:  0.4542308
# G_loss:  1.8940954
# reconstruction_loss:  1.3094698
# dA_loss: 0.27238125
# DB_loss: 0.18184955
#
#
# Epoch---------------- 91 / 100
# Loop index---------------- 9 / 30
# D_loss:  0.5212673
# G_loss:  2.2751422
# reconstruction_loss:  1.6472073
# dA_loss: 0.28899097
# DB_loss: 0.23227634
#
#
# Epoch---------------- 91 / 100
# Loop index---------------- 10 / 30
# D_loss:  0.3691265
# G_loss:  2.35139
# reconstruction_loss:  1.6534297
# dA_loss: 0.3007608
# DB_loss: 0.06836569
#
#
# Epoch---------------- 91 / 100
# Loop index---------------- 11 / 30
# D_loss:  0.4095773
# G_loss:  2.0997152
# reconstruction_loss:  1.5234019
# dA_loss: 0.22522579
# DB_loss: 0.18435152
#
#
# Epoch---------------- 91 / 100
# Loop index---------------- 12 / 30
# D_loss:  0.2533194
# G_loss:  2.451561
# reconstruction_loss:  1.8456023
# dA_loss: 0.20788679
# DB_loss: 0.045432627
#
#
# Epoch---------------- 91 / 100
# Loop index---------------- 13 / 30
# D_loss:  0.6775652
# G_loss:  2.3488336
# reconstruction_loss:  1.4912354
# dA_loss: 0.35650647
# DB_loss: 0.32105875
#
#
# Epoch---------------- 91 / 100
# Loop index---------------- 14 / 30
# D_loss:  0.44153106
# G_loss:  2.1755486
# reconstruction_loss:  1.415618
# dA_loss: 0.3155359
# DB_loss: 0.12599516
#
#
# Epoch---------------- 91 / 100
# Loop index---------------- 15 / 30
# D_loss:  0.3464385
# G_loss:  2.377044
# reconstruction_loss:  1.5134625
# dA_loss: 0.22899127
# DB_loss: 0.11744723
#
#
# Epoch---------------- 91 / 100
# Loop index---------------- 16 / 30
# D_loss:  0.49263895
# G_loss:  2.033053
# ...
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 5 / 30
# D_loss:  0.47205323
# G_loss:  2.2703316
# reconstruction_loss:  1.6011927
# dA_loss: 0.30898514
# DB_loss: 0.16306809
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 6 / 30
# D_loss:  0.31603822
# G_loss:  2.6763058
# reconstruction_loss:  1.9141953
# dA_loss: 0.2423828
# DB_loss: 0.07365543
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 7 / 30
# D_loss:  0.32356584
# G_loss:  2.2401075
# reconstruction_loss:  1.4981405
# dA_loss: 0.13630699
# DB_loss: 0.18725884
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 8 / 30
# D_loss:  0.33247507
# G_loss:  3.1266892
# reconstruction_loss:  2.3782122
# dA_loss: 0.27305126
# DB_loss: 0.059423793
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 9 / 30
# D_loss:  0.5830957
# G_loss:  2.327343
# reconstruction_loss:  1.5720806
# dA_loss: 0.52228934
# DB_loss: 0.0608064
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 10 / 30
# D_loss:  0.7885928
# G_loss:  2.4313917
# reconstruction_loss:  1.5791583
# dA_loss: 0.2676274
# DB_loss: 0.52096546
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 11 / 30
# D_loss:  0.5046751
# G_loss:  2.2222364
# reconstruction_loss:  1.4722536
# dA_loss: 0.34446394
# DB_loss: 0.16021113
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 12 / 30
# D_loss:  0.5913917
# G_loss:  2.713297
# reconstruction_loss:  2.0353663
# dA_loss: 0.32255423
# DB_loss: 0.26883745
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 13 / 30
# D_loss:  0.4367798
# G_loss:  2.388554
# reconstruction_loss:  1.6613444
# dA_loss: 0.3347782
# DB_loss: 0.10200162
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 14 / 30
# D_loss:  0.91934615
# G_loss:  2.098495
# reconstruction_loss:  1.2862186
# dA_loss: 0.43519115
# DB_loss: 0.484155
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 15 / 30
# D_loss:  0.41264108
# G_loss:  2.4295716
# reconstruction_loss:  1.5523281
# dA_loss: 0.33492494
# DB_loss: 0.07771614
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 16 / 30
# D_loss:  0.5947466
# G_loss:  2.0973935
# reconstruction_loss:  1.2819964
# dA_loss: 0.2905493
# DB_loss: 0.30419725
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 17 / 30
# D_loss:  0.49075472
# G_loss:  2.29003
# reconstruction_loss:  1.5901036
# dA_loss: 0.33455855
# DB_loss: 0.15619618
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 18 / 30
# D_loss:  0.37180167
# G_loss:  2.1228714
# reconstruction_loss:  1.4968538
# dA_loss: 0.29426426
# DB_loss: 0.07753742
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 19 / 30
# D_loss:  0.3585046
# G_loss:  2.0957716
# reconstruction_loss:  1.392872
# dA_loss: 0.29233646
# DB_loss: 0.06616812
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 20 / 30
# D_loss:  0.5798323
# G_loss:  2.050054
# reconstruction_loss:  1.4188282
# dA_loss: 0.25965482
# DB_loss: 0.3201775
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 21 / 30
# D_loss:  0.403903
# G_loss:  2.1113439
# reconstruction_loss:  1.399059
# dA_loss: 0.26347023
# DB_loss: 0.14043279
# Time passed 0:16:55 : ETA in 0:00:24
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 22 / 30
# D_loss:  0.43181276
# G_loss:  2.156488
# reconstruction_loss:  1.4713011
# dA_loss: 0.24681073
# DB_loss: 0.18500204
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 23 / 30
# D_loss:  0.31426585
# G_loss:  2.237823
# reconstruction_loss:  1.5553408
# dA_loss: 0.22548002
# DB_loss: 0.08878582
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 24 / 30
# D_loss:  0.46288115
# G_loss:  1.9625417
# reconstruction_loss:  1.3074976
# dA_loss: 0.2843337
# DB_loss: 0.17854746
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 25 / 30
# D_loss:  0.44950145
# G_loss:  2.1537557
# reconstruction_loss:  1.5233616
# dA_loss: 0.32921025
# DB_loss: 0.1202912
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 26 / 30
# D_loss:  0.29702458
# G_loss:  2.3134074
# reconstruction_loss:  1.7031531
# dA_loss: 0.2260822
# DB_loss: 0.070942365
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 27 / 30
# D_loss:  0.41236773
# G_loss:  2.0719566
# reconstruction_loss:  1.3592509
# dA_loss: 0.32035142
# DB_loss: 0.09201631
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 28 / 30
# D_loss:  0.36781996
# G_loss:  2.4512227
# reconstruction_loss:  1.8092992
# dA_loss: 0.20478258
# DB_loss: 0.16303739
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 29 / 30
# D_loss:  0.49909288
# G_loss:  1.9968421
# reconstruction_loss:  1.35735
# dA_loss: 0.2972228
# DB_loss: 0.20187008
#
#
# Epoch---------------- 98 / 100
# Loop index---------------- 30 / 30
# D_loss:  0.25793165
# G_loss:  2.4206133
# reconstruction_loss:  1.7597263
# dA_loss: 0.20351017
# DB_loss: 0.05442147
#
#
#  -------------------------Saving images for epoch 98 -------------------------
#
#
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 1 / 30
# D_loss:  0.42154688
# G_loss:  2.203826
# reconstruction_loss:  1.5789529
# dA_loss: 0.28532147
# DB_loss: 0.13622539
# Time passed 0:16:58 : ETA in 0:00:21
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 2 / 30
# D_loss:  0.3117371
# G_loss:  2.2793117
# reconstruction_loss:  1.6442621
# dA_loss: 0.17630829
# DB_loss: 0.1354288
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 3 / 30
# D_loss:  0.4254595
# G_loss:  2.4893014
# reconstruction_loss:  1.7197182
# dA_loss: 0.36493313
# DB_loss: 0.060526386
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 4 / 30
# D_loss:  0.61199373
# G_loss:  2.225157
# reconstruction_loss:  1.4811552
# dA_loss: 0.3849632
# DB_loss: 0.22703052
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 5 / 30
# D_loss:  0.47672883
# G_loss:  2.43042
# reconstruction_loss:  1.6341872
# dA_loss: 0.23847368
# DB_loss: 0.23825514
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 6 / 30
# D_loss:  0.31819582
# G_loss:  2.1401725
# reconstruction_loss:  1.5123202
# dA_loss: 0.2535237
# DB_loss: 0.06467213
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 7 / 30
# D_loss:  0.31032318
# G_loss:  2.0850008
# reconstruction_loss:  1.3853967
# dA_loss: 0.24546301
# DB_loss: 0.06486015
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 8 / 30
# D_loss:  0.44839814
# G_loss:  2.1699333
# reconstruction_loss:  1.5876603
# dA_loss: 0.24060234
# DB_loss: 0.2077958
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 9 / 30
# D_loss:  0.32242346
# G_loss:  2.25425
# reconstruction_loss:  1.6308272
# dA_loss: 0.28056273
# DB_loss: 0.041860722
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 10 / 30
# D_loss:  0.53186333
# G_loss:  2.1558905
# reconstruction_loss:  1.4437048
# dA_loss: 0.21986908
# DB_loss: 0.31199422
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 11 / 30
# D_loss:  0.4760793
# G_loss:  2.6883874
# reconstruction_loss:  1.8775132
# dA_loss: 0.28013277
# DB_loss: 0.19594651
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 12 / 30
# D_loss:  0.38030684
# G_loss:  2.6212342
# reconstruction_loss:  1.880002
# dA_loss: 0.16855413
# DB_loss: 0.21175273
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 13 / 30
# D_loss:  0.34514818
# G_loss:  2.2965498
# reconstruction_loss:  1.5561165
# dA_loss: 0.2814377
# DB_loss: 0.06371048
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 14 / 30
# D_loss:  0.26034862
# G_loss:  2.4990292
# reconstruction_loss:  1.6891339
# dA_loss: 0.19955793
# DB_loss: 0.060790703
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 15 / 30
# D_loss:  0.41135263
# G_loss:  2.569117
# reconstruction_loss:  1.9266074
# dA_loss: 0.2778707
# DB_loss: 0.13348193
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 16 / 30
# D_loss:  0.43750608
# G_loss:  1.9967504
# reconstruction_loss:  1.3386784
# dA_loss: 0.25278878
# DB_loss: 0.1847173
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 17 / 30
# D_loss:  0.31320602
# G_loss:  2.4358168
# reconstruction_loss:  1.8076291
# dA_loss: 0.2032146
# DB_loss: 0.1099914
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 18 / 30
# D_loss:  0.35613406
# G_loss:  2.2041588
# reconstruction_loss:  1.5636655
# dA_loss: 0.24476948
# DB_loss: 0.11136458
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 19 / 30
# D_loss:  0.56232595
# G_loss:  2.3237257
# reconstruction_loss:  1.645694
# dA_loss: 0.23417082
# DB_loss: 0.32815516
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 20 / 30
# D_loss:  0.3029772
# G_loss:  2.4732096
# reconstruction_loss:  1.7421521
# dA_loss: 0.24437627
# DB_loss: 0.058600925
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 21 / 30
# D_loss:  0.42510885
# G_loss:  2.2994893
# reconstruction_loss:  1.4261379
# dA_loss: 0.1987518
# DB_loss: 0.22635703
# Time passed 0:17:04 : ETA in 0:00:14
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 22 / 30
# D_loss:  0.30157995
# G_loss:  2.8558857
# reconstruction_loss:  2.0775862
# dA_loss: 0.20009926
# DB_loss: 0.10148068
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 23 / 30
# D_loss:  0.47030792
# G_loss:  2.2452846
# reconstruction_loss:  1.5445971
# dA_loss: 0.2678612
# DB_loss: 0.20244673
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 24 / 30
# D_loss:  0.430897
# G_loss:  2.3373263
# reconstruction_loss:  1.681805
# dA_loss: 0.35448995
# DB_loss: 0.07640703
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 25 / 30
# D_loss:  0.36737216
# G_loss:  2.2610135
# reconstruction_loss:  1.5054631
# dA_loss: 0.26522368
# DB_loss: 0.10214846
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 26 / 30
# D_loss:  0.52040094
# G_loss:  2.2039895
# reconstruction_loss:  1.5017042
# dA_loss: 0.29102388
# DB_loss: 0.22937705
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 27 / 30
# D_loss:  0.32576525
# G_loss:  2.4325175
# reconstruction_loss:  1.6879652
# dA_loss: 0.27507362
# DB_loss: 0.050691642
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 28 / 30
# D_loss:  0.47124034
# G_loss:  2.2679358
# reconstruction_loss:  1.5598176
# dA_loss: 0.12264135
# DB_loss: 0.348599
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 29 / 30
# D_loss:  0.40032429
# G_loss:  2.467351
# reconstruction_loss:  1.5884644
# dA_loss: 0.32317874
# DB_loss: 0.07714553
#
#
# Epoch---------------- 99 / 100
# Loop index---------------- 30 / 30
# D_loss:  0.34782887
# G_loss:  2.2284012
# reconstruction_loss:  1.5190711
# dA_loss: 0.26658493
# DB_loss: 0.08124395
#
#
#  -------------------------Saving images for epoch 99 -------------------------
#
#
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 1 / 30
# D_loss:  0.39674267
# G_loss:  2.2490861
# reconstruction_loss:  1.575245
# dA_loss: 0.23381028
# DB_loss: 0.1629324
# Time passed 0:17:08 : ETA in 0:00:10
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 2 / 30
# D_loss:  0.31217954
# G_loss:  2.5586839
# reconstruction_loss:  1.8700743
# dA_loss: 0.27579674
# DB_loss: 0.036382794
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 3 / 30
# D_loss:  0.61613345
# G_loss:  2.1680875
# reconstruction_loss:  1.4450045
# dA_loss: 0.45958567
# DB_loss: 0.15654781
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 4 / 30
# D_loss:  0.4251467
# G_loss:  2.2784536
# reconstruction_loss:  1.5512372
# dA_loss: 0.3078434
# DB_loss: 0.1173033
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 5 / 30
# D_loss:  0.28408897
# G_loss:  2.2921972
# reconstruction_loss:  1.6502724
# dA_loss: 0.23097968
# DB_loss: 0.0531093
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 6 / 30
# D_loss:  0.46036753
# G_loss:  2.2276535
# reconstruction_loss:  1.582939
# dA_loss: 0.3079078
# DB_loss: 0.15245974
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 7 / 30
# D_loss:  0.50494635
# G_loss:  3.492413
# reconstruction_loss:  2.8812504
# dA_loss: 0.24560007
# DB_loss: 0.25934625
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 8 / 30
# D_loss:  0.35767657
# G_loss:  2.3932557
# reconstruction_loss:  1.6540747
# dA_loss: 0.2648044
# DB_loss: 0.09287218
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 9 / 30
# D_loss:  0.56581604
# G_loss:  2.1871514
# reconstruction_loss:  1.3566406
# dA_loss: 0.22745258
# DB_loss: 0.33836344
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 10 / 30
# D_loss:  0.42883682
# G_loss:  2.3465605
# reconstruction_loss:  1.6413586
# dA_loss: 0.23864841
# DB_loss: 0.19018841
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 11 / 30
# D_loss:  0.36306897
# G_loss:  2.288508
# reconstruction_loss:  1.6294833
# dA_loss: 0.24477868
# DB_loss: 0.11829029
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 12 / 30
# D_loss:  0.33780196
# G_loss:  2.281156
# reconstruction_loss:  1.6656106
# dA_loss: 0.22280028
# DB_loss: 0.11500168
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 13 / 30
# D_loss:  0.35779572
# G_loss:  2.203096
# reconstruction_loss:  1.437746
# dA_loss: 0.23252597
# DB_loss: 0.12526976
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 14 / 30
# D_loss:  0.36782268
# G_loss:  2.4161692
# reconstruction_loss:  1.6894926
# dA_loss: 0.25713474
# DB_loss: 0.11068794
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 15 / 30
# D_loss:  0.37437117
# G_loss:  2.253676
# reconstruction_loss:  1.5165567
# dA_loss: 0.3235131
# DB_loss: 0.050858065
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 16 / 30
# D_loss:  0.65951574
# G_loss:  2.1118317
# reconstruction_loss:  1.3772354
# dA_loss: 0.26722965
# DB_loss: 0.39228606
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 17 / 30
# D_loss:  0.45154393
# G_loss:  2.5422134
# reconstruction_loss:  1.8368144
# dA_loss: 0.24377385
# DB_loss: 0.2077701
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 18 / 30
# D_loss:  0.38172477
# G_loss:  2.257197
# reconstruction_loss:  1.5318006
# dA_loss: 0.20951489
# DB_loss: 0.17220989
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 19 / 30
# D_loss:  0.34242442
# G_loss:  2.491468
# reconstruction_loss:  1.860398
# dA_loss: 0.1893253
# DB_loss: 0.15309912
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 20 / 30
# D_loss:  0.39501137
# G_loss:  2.881769
# reconstruction_loss:  2.2481651
# dA_loss: 0.15405685
# DB_loss: 0.24095452
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 21 / 30
# D_loss:  0.37852272
# G_loss:  2.5054166
# reconstruction_loss:  1.8251054
# dA_loss: 0.18289226
# DB_loss: 0.19563046
# Time passed 0:17:14 : ETA in 0:00:03
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 22 / 30
# D_loss:  0.24228561
# G_loss:  2.481274
# reconstruction_loss:  1.759804
# dA_loss: 0.20665488
# DB_loss: 0.035630725
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 23 / 30
# D_loss:  0.51781416
# G_loss:  2.2026706
# reconstruction_loss:  1.437682
# dA_loss: 0.3485073
# DB_loss: 0.16930689
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 24 / 30
# D_loss:  0.40795368
# G_loss:  2.4439478
# reconstruction_loss:  1.6968626
# dA_loss: 0.32468188
# DB_loss: 0.08327182
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 25 / 30
# D_loss:  0.45942387
# G_loss:  2.129061
# reconstruction_loss:  1.3811412
# dA_loss: 0.2725193
# DB_loss: 0.18690458
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 26 / 30
# D_loss:  0.33086926
# G_loss:  2.2837582
# reconstruction_loss:  1.588541
# dA_loss: 0.21337432
# DB_loss: 0.117494926
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 27 / 30
# D_loss:  0.43628275
# G_loss:  2.3345773
# reconstruction_loss:  1.5983486
# dA_loss: 0.28109124
# DB_loss: 0.1551915
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 28 / 30
# D_loss:  0.4586908
# G_loss:  2.3436012
# reconstruction_loss:  1.62431
# dA_loss: 0.35511354
# DB_loss: 0.103577256
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 29 / 30
# D_loss:  0.5213925
# G_loss:  2.2866206
# reconstruction_loss:  1.5008591
# dA_loss: 0.31573358
# DB_loss: 0.20565894
#
#
# Epoch---------------- 100 / 100
# Loop index---------------- 30 / 30
# D_loss:  0.42766103
# G_loss:  2.0378976
# reconstruction_loss:  1.3692838
# dA_loss: 0.26981288
# DB_loss: 0.15784815
#
#
#  -------------------------Saving images for epoch 100 -------------------------
#
#
# D_A_model has been saved in saved_models/20210610-095330/
# D_B_model has been saved in saved_models/20210610-095330/
# G_A2B_model has been saved in saved_models/20210610-095330/
# G_B2A_model has been saved in saved_models/20210610-095330/

# %%
from google.colab import files
#For the folder you have to zip it first and can only download later on
# !zip -r 20210610-095330.zip images/20210610-095330
#Download files
files.download('20210610-095330.zip')
# Out:
#   adding: images/20210610-095330/ (stored 0%)
#   adding: images/20210610-095330/Btest/ (stored 0%)
#   adding: images/20210610-095330/Btest/epoch82_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch38_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch1_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch60_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch62_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch51_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch40_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch36_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch42_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch48_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch61_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch26_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch4_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch9_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch24_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch90_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch31_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch98_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch78_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch80_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch52_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch28_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch44_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch87_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch49_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch47_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch91_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch69_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch92_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch43_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch63_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch67_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch88_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch29_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch71_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch11_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch12_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch68_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch16_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch23_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch30_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch34_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch66_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch20_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch45_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch54_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch50_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch32_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch77_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch35_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch27_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch8_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch6_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch95_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch84_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch73_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch53_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch39_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch5_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch58_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch96_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch18_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch41_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch10_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch19_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch97_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch22_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch7_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch99_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch13_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch75_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch17_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch14_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch37_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch15_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch100_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch72_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch76_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch2_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch93_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch55_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch33_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch65_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch70_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch64_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch79_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch94_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch59_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch86_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch46_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch3_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch81_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch21_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch74_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch57_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch89_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch25_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch83_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch85_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Btest/epoch56_sample1.png (deflated 0%)
#   adding: images/20210610-095330/loss_output.csv (deflated 64%)
#   adding: images/20210610-095330/B/ (stored 0%)
#   adding: images/20210610-095330/B/epoch60_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch40_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch34_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch91_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch50_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch66_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch1_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch70_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch77_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch76_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch29_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch80_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch2_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch95_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch78_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch71_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch26_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch98_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch84_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch39_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch19_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch75_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch86_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch41_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch72_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch44_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch31_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch64_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch3_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch21_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch14_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch5_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch85_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch43_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch22_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch47_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch28_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch59_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch68_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch35_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch65_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch18_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch69_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch42_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch56_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch94_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch88_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch83_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch73_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch8_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch12_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch48_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch46_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch4_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch52_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch58_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch55_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch79_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch90_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch89_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch61_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch20_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch100_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch97_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch82_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch15_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch23_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch99_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch93_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch67_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch13_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch7_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch32_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch81_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch96_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch57_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch25_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch63_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch53_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch62_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch9_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch30_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch27_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch54_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch51_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch45_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch10_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch49_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch6_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch11_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch16_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch74_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch92_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch38_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch87_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch36_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch33_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch24_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch17_sample0.png (deflated 0%)
#   adding: images/20210610-095330/B/epoch37_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/ (stored 0%)
#   adding: images/20210610-095330/A/epoch60_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch40_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch34_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch91_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch50_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch66_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch1_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch70_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch77_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch76_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch29_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch80_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch2_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch95_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch78_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch71_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch26_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch98_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch84_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch39_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch19_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch75_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch86_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch41_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch72_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch44_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch31_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch64_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch3_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch21_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch14_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch5_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch85_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch43_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch22_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch47_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch28_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch59_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch68_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch35_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch65_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch18_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch69_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch42_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch56_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch94_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch88_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch83_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch73_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch8_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch12_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch48_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch46_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch4_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch52_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch58_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch55_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch79_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch90_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch89_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch61_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch20_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch100_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch97_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch82_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch15_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch23_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch99_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch93_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch67_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch13_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch7_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch32_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch81_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch96_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch57_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch25_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch63_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch53_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch62_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch9_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch30_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch27_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch54_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch51_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch45_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch10_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch49_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch6_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch11_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch16_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch74_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch92_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch38_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch87_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch36_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch33_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch24_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch17_sample0.png (deflated 0%)
#   adding: images/20210610-095330/A/epoch37_sample0.png (deflated 0%)
#   adding: images/20210610-095330/Atest/ (stored 0%)
#   adding: images/20210610-095330/Atest/epoch82_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch38_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch1_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch60_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch62_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch51_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch40_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch36_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch42_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch48_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch61_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch26_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch4_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch9_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch24_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch90_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch31_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch98_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch78_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch80_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch52_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch28_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch44_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch87_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch49_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch47_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch91_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch69_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch92_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch43_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch63_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch67_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch88_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch29_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch71_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch11_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch12_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch68_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch16_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch23_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch30_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch34_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch66_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch20_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch45_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch54_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch50_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch32_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch77_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch35_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch27_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch8_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch6_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch95_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch84_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch73_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch53_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch39_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch5_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch58_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch96_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch18_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch41_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch10_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch19_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch97_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch22_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch7_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch99_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch13_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch75_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch17_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch14_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch37_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch15_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch100_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch72_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch76_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch2_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch93_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch55_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch33_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch65_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch70_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch64_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch79_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch94_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch59_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch86_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch46_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch3_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch81_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch21_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch74_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch57_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch89_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch25_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch83_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch85_sample1.png (deflated 0%)
#   adding: images/20210610-095330/Atest/epoch56_sample1.png (deflated 0%)
#   adding: images/20210610-095330/meta_data.json (deflated 53%)
#   adding: images/20210610-095330/tmp.png (deflated 0%)
